# %%
import pandas as pd
import os

# %%
df = pd.read_csv('data/2018_Central_Park_Squirrel_Data.csv') # Relative path

# %%
 # df = pd.read_csv('/Users/boychinov/Git/eurotech_ds/data/2018_Central_Park_Squirrel_Data.csv') # Absolute path

# %%
# For Windows Users
# df_squirrel = pd.read_csv("C:/Users/NG/Documents/git/pandas_matplotlib/data/2018_Central_Park_Squirrel_Data.csv")
# df_squirrel = pd.read_csv("C:\\Users\\NG\\Documents\\git\\pandas_matplotlib\\data\\2018_Central_Park_Squirrel_Data.csv")
# df_squirrel = pd.read_csv(r"C:\Users\NG\Documents\git\pandas_matplotlib\data\2018_Central_Park_Squirrel_Data.csv")

# %%
cwd = os.getcwd()

# %%
cwd
# Out:
# '/Users/boychinov/Git/eurotech_ds'

# %%
file_path = os.path.join(cwd, 'data', '2018_Central_Park_Squirrel_Data.csv')

# %%
file_path
# Out:
# '/Users/boychinov/Git/eurotech_ds/data/2018_Central_Park_Squirrel_Data.csv'

# %%
df1 = pd.read_csv('data/people_info.csv', sep='\t')

# %%
df1.head()
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df.head()
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    Hectare Squirrel Number       Age Primary Fur Color Highlight Fur Color  \
# 0                        3       NaN               NaN                 NaN
# 1                        3     Adult              Gray            Cinnamon
# 2                        3     Adult          Cinnamon                 NaN
# 3                        5  Juvenile              Gray                 NaN
# 4                        1       NaN               NaN                 NaN
#
#    ...   Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# ...

# %%
df.columns
# Out:
# Index(['X', 'Y', 'Unique Squirrel ID', 'Hectare', 'Shift', 'Date',
#        'Hectare Squirrel Number', 'Age', 'Primary Fur Color',
#        'Highlight Fur Color', 'Combination of Primary and Highlight Color',
#        'Color notes', 'Location', 'Above Ground Sighter Measurement',
#        'Specific Location', 'Running', 'Chasing', 'Climbing', 'Eating',
#        'Foraging', 'Other Activities', 'Kuks', 'Quaas', 'Moans', 'Tail flags',
#        'Tail twitches', 'Approaches', 'Indifferent', 'Runs from',
#        'Other Interactions', 'Lat/Long'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
upper=[]
for i in list(df.columns):
    upper.append(i.upper())

# %%
upper
# Out:
# ['X',
#  'Y',
#  'UNIQUE SQUIRREL ID',
#  'HECTARE',
#  'SHIFT',
#  'DATE',
#  'HECTARE SQUIRREL NUMBER',
#  'AGE',
#  'PRIMARY FUR COLOR',
#  'HIGHLIGHT FUR COLOR',
#  'COMBINATION OF PRIMARY AND HIGHLIGHT COLOR',
#  'COLOR NOTES',
#  'LOCATION',
#  'ABOVE GROUND SIGHTER MEASUREMENT',
#  'SPECIFIC LOCATION',
#  'RUNNING',
#  'CHASING',
#  'CLIMBING',
#  'EATING',
#  'FORAGING',
#  'OTHER ACTIVITIES',
#  'KUKS',
#  'QUAAS',
#  'MOANS',
#  'TAIL FLAGS',
#  'TAIL TWITCHES',
#  'APPROACHES',
#  'INDIFFERENT',
#  'RUNS FROM',
#  'OTHER INTERACTIONS',
#  'LAT/LONG']

# %%
df.columns.str.upper()
# Out:
# Index(['X', 'Y', 'UNIQUE SQUIRREL ID', 'HECTARE', 'SHIFT', 'DATE',
#        'HECTARE SQUIRREL NUMBER', 'AGE', 'PRIMARY FUR COLOR',
#        'HIGHLIGHT FUR COLOR', 'COMBINATION OF PRIMARY AND HIGHLIGHT COLOR',
#        'COLOR NOTES', 'LOCATION', 'ABOVE GROUND SIGHTER MEASUREMENT',
#        'SPECIFIC LOCATION', 'RUNNING', 'CHASING', 'CLIMBING', 'EATING',
#        'FORAGING', 'OTHER ACTIVITIES', 'KUKS', 'QUAAS', 'MOANS', 'TAIL FLAGS',
#        'TAIL TWITCHES', 'APPROACHES', 'INDIFFERENT', 'RUNS FROM',
#        'OTHER INTERACTIONS', 'LAT/LONG'],
#       dtype='object')

# %%
upper = [i.upper() for i in list(df.columns)]

# %%
upper
# Out:
# ['X',
#  'Y',
#  'UNIQUE SQUIRREL ID',
#  'HECTARE',
#  'SHIFT',
#  'DATE',
#  'HECTARE SQUIRREL NUMBER',
#  'AGE',
#  'PRIMARY FUR COLOR',
#  'HIGHLIGHT FUR COLOR',
#  'COMBINATION OF PRIMARY AND HIGHLIGHT COLOR',
#  'COLOR NOTES',
#  'LOCATION',
#  'ABOVE GROUND SIGHTER MEASUREMENT',
#  'SPECIFIC LOCATION',
#  'RUNNING',
#  'CHASING',
#  'CLIMBING',
#  'EATING',
#  'FORAGING',
#  'OTHER ACTIVITIES',
#  'KUKS',
#  'QUAAS',
#  'MOANS',
#  'TAIL FLAGS',
#  'TAIL TWITCHES',
#  'APPROACHES',
#  'INDIFFERENT',
#  'RUNS FROM',
#  'OTHER INTERACTIONS',
#  'LAT/LONG']

# %%
a = map(str.upper, df.columns)

# %%
list(a)
# Out:
# ['X',
#  'Y',
#  'UNIQUE SQUIRREL ID',
#  'HECTARE',
#  'SHIFT',
#  'DATE',
#  'HECTARE SQUIRREL NUMBER',
#  'AGE',
#  'PRIMARY FUR COLOR',
#  'HIGHLIGHT FUR COLOR',
#  'COMBINATION OF PRIMARY AND HIGHLIGHT COLOR',
#  'COLOR NOTES',
#  'LOCATION',
#  'ABOVE GROUND SIGHTER MEASUREMENT',
#  'SPECIFIC LOCATION',
#  'RUNNING',
#  'CHASING',
#  'CLIMBING',
#  'EATING',
#  'FORAGING',
#  'OTHER ACTIVITIES',
#  'KUKS',
#  'QUAAS',
#  'MOANS',
#  'TAIL FLAGS',
#  'TAIL TWITCHES',
#  'APPROACHES',
#  'INDIFFERENT',
#  'RUNS FROM',
#  'OTHER INTERACTIONS',
#  'LAT/LONG']

# %%
df.columns = upper

# %%
df.head()
# Out:
#            X          Y UNIQUE SQUIRREL ID HECTARE SHIFT      DATE  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    HECTARE SQUIRREL NUMBER       AGE PRIMARY FUR COLOR HIGHLIGHT FUR COLOR  \
# 0                        3       NaN               NaN                 NaN
# 1                        3     Adult              Gray            Cinnamon
# 2                        3     Adult          Cinnamon                 NaN
# 3                        5  Juvenile              Gray                 NaN
# 4                        1       NaN               NaN                 NaN
#
#    ...   KUKS  QUAAS  MOANS TAIL FLAGS TAIL TWITCHES  APPROACHES  INDIFFERENT  \
# ...

# %%
df['HECTARE'].str.replace('N', 'F')
# Out:
# 0       37F
# 1       37E
# 2       02E
# 3       05D
# 4       39B
#        ...
# 3018    30B
# 3019    19A
# 3020    22D
# 3021    29B
# 3022    05E
# Name: HECTARE, Length: 3023, dtype: object

# %%
df.columns.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df.columns.upper()
#
# AttributeError: 'Index' object has no attribute 'upper'

# %%
df.loc[2, ['X', 'Y']]
# Out:
# X   -73.976831
# Y    40.766718
# Name: 2, dtype: object

# %%
df.iloc[2, [0, 1]]
# Out:
# X   -73.976831
# Y    40.766718
# Name: 2, dtype: object

# %%
df.head()
# Out:
#            X          Y UNIQUE SQUIRREL ID HECTARE SHIFT      DATE  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    HECTARE SQUIRREL NUMBER       AGE PRIMARY FUR COLOR HIGHLIGHT FUR COLOR  \
# 0                        3       NaN               NaN                 NaN
# 1                        3     Adult              Gray            Cinnamon
# 2                        3     Adult          Cinnamon                 NaN
# 3                        5  Juvenile              Gray                 NaN
# 4                        1       NaN               NaN                 NaN
#
#    ...   KUKS  QUAAS  MOANS TAIL FLAGS TAIL TWITCHES  APPROACHES  INDIFFERENT  \
# ...

# %%
df.set_index('UNIQUE SQUIRREL ID', inplace=True)

# %%
df.head()
# Out:
#                             X          Y HECTARE SHIFT      DATE  \
# UNIQUE SQUIRREL ID
# 37F-PM-1014-03     -73.956134  40.794082     37F    PM  10142018
# 37E-PM-1006-03     -73.957044  40.794851     37E    PM  10062018
# 2E-AM-1010-03      -73.976831  40.766718     02E    AM  10102018
# 5D-PM-1018-05      -73.975725  40.769703     05D    PM  10182018
# 39B-AM-1018-01     -73.959313  40.797533     39B    AM  10182018
#
#                     HECTARE SQUIRREL NUMBER       AGE PRIMARY FUR COLOR  \
# UNIQUE SQUIRREL ID
# 37F-PM-1014-03                            3       NaN               NaN
# 37E-PM-1006-03                            3     Adult              Gray
# 2E-AM-1010-03                             3     Adult          Cinnamon
# 5D-PM-1018-05                             5  Juvenile              Gray
# 39B-AM-1018-01                            1       NaN               NaN
#
#                    HIGHLIGHT FUR COLOR  \
# UNIQUE SQUIRREL ID
# ...

# %%
df.iloc[2:3, 0:2]
# Out:
#   UNIQUE SQUIRREL ID          X
# 2      2E-AM-1010-03 -73.976831

# %%
df.loc['2E-AM-1010-03', ['X', 'Y']]
# Out:
# X   -73.976831
# Y    40.766718
# Name: 2E-AM-1010-03, dtype: object

# %%
df.iloc[2, [0, 1]]
# Out:
# X   -73.976831
# Y    40.766718
# Name: 2E-AM-1010-03, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#   UNIQUE SQUIRREL ID          X          Y HECTARE SHIFT      DATE  \
# 0     37F-PM-1014-03 -73.956134  40.794082     37F    PM  10142018
# 1     37E-PM-1006-03 -73.957044  40.794851     37E    PM  10062018
# 2      2E-AM-1010-03 -73.976831  40.766718     02E    AM  10102018
# 3      5D-PM-1018-05 -73.975725  40.769703     05D    PM  10182018
# 4     39B-AM-1018-01 -73.959313  40.797533     39B    AM  10182018
#
#    HECTARE SQUIRREL NUMBER       AGE PRIMARY FUR COLOR HIGHLIGHT FUR COLOR  \
# 0                        3       NaN               NaN                 NaN
# 1                        3     Adult              Gray            Cinnamon
# 2                        3     Adult          Cinnamon                 NaN
# 3                        5  Juvenile              Gray                 NaN
# 4                        1       NaN               NaN                 NaN
#
#    ...   KUKS  QUAAS  MOANS TAIL FLAGS TAIL TWITCHES  APPROACHES  INDIFFERENT  \
# ...

# %%
df.shape[0] == df['UNIQUE SQUIRREL ID'].nunique()
# Out:
# False

# %%
df['UNIQUE SQUIRREL ID'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3018    False
# 3019    False
# 3020    False
# 3021    False
# 3022    False
# Name: UNIQUE SQUIRREL ID, Length: 3023, dtype: bool

# %%
df[df['Age'] > 30]

# %%
df[df['UNIQUE SQUIRREL ID'].duplicated(keep=False)].sort_values('UNIQUE SQUIRREL ID')
# Out:
#      UNIQUE SQUIRREL ID          X          Y HECTARE SHIFT      DATE  \
# 2532      1F-AM-1010-04 -73.976620  40.766191     01F    AM  10102018
# 2613      1F-AM-1010-04 -73.976588  40.766095     01F    AM  10102018
# 1        37E-PM-1006-03 -73.957044  40.794851     37E    PM  10062018
# 2271     37E-PM-1006-03 -73.956967  40.794879     37E    PM  10062018
# 1539     40B-AM-1019-06 -73.957711  40.798406     40B    AM  10192018
# 2167     40B-AM-1019-06 -73.958236  40.798775     40B    AM  10192018
# 2106      4C-PM-1010-05 -73.977262  40.769282     04C    PM  10102018
# 2888      4C-PM-1010-05 -73.977165  40.769305     04C    PM  10102018
# 519       7D-PM-1010-01 -73.974945  40.772066     07D    PM  10102018
# 2234      7D-PM-1010-01 -73.974852  40.771959     07D    PM  10102018
#
#       HECTARE SQUIRREL NUMBER       AGE PRIMARY FUR COLOR HIGHLIGHT FUR COLOR  \
# 2532                        4     Adult              Gray                 NaN
# ...

# %%
df['X'].astype(str) + '_' + df['Y'].astype(str)
# Out:
# 0       -73.9561344937861_40.7940823884086
# 1       -73.9570437717691_40.7948509408039
# 2       -73.9768311751004_40.7667178072558
# 3       -73.9757249834141_40.7697032606755
# 4        -73.9593126695714_40.797533370163
#                        ...
# 3018    -73.9639431360458_40.7908677445466
# 3019    -73.9704015859639_40.7825600069973
# 3020    -73.9665871993517_40.7836775064883
# 3021    -73.9639941227864_40.7899152327912
# 3022    -73.9754794191553_40.7696404489025
# Length: 3023, dtype: object

# %%
df.is
# Out:
# UNIQUE SQUIRREL ID                               0
# X                                                0
# Y                                                0
# HECTARE                                          0
# SHIFT                                            0
# DATE                                             0
# HECTARE SQUIRREL NUMBER                          0
# AGE                                            121
# PRIMARY FUR COLOR                               55
# HIGHLIGHT FUR COLOR                           1086
# COMBINATION OF PRIMARY AND HIGHLIGHT COLOR       0
# COLOR NOTES                                   2841
# LOCATION                                        64
# ABOVE GROUND SIGHTER MEASUREMENT               114
# SPECIFIC LOCATION                             2547
# RUNNING                                          0
# CHASING                                          0
# CLIMBING                                         0
# ...
