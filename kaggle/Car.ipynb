# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../data/Car.csv")
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.isnull().mean()
# Out:
# Make                 0.000000
# Model                0.000000
# Year                 0.000000
# Engine Fuel Type     0.000252
# Engine HP            0.005792
# Engine Cylinders     0.002518
# Transmission Type    0.000000
# Driven_Wheels        0.000000
# Number of Doors      0.000504
# Market Category      0.314084
# Vehicle Size         0.000000
# Vehicle Style        0.000000
# highway MPG          0.000000
# city mpg             0.000000
# Popularity           0.000000
# MSRP                 0.000000
# dtype: float64

# %%
df.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(715)

# %%
df[df.duplicated(keep=False)].sort_values(by=["Make",	"Model",	"Year",	"MSRP"])
# Out:
#         Make Model  Year             Engine Fuel Type  Engine HP  \
# 8536   Acura    RL  2010  premium unleaded (required)      300.0
# 8537   Acura    RL  2010  premium unleaded (required)      300.0
# 8539   Acura    RL  2011  premium unleaded (required)      300.0
# 8540   Acura    RL  2011  premium unleaded (required)      300.0
# 8544   Acura    RL  2012  premium unleaded (required)      300.0
# ...      ...   ...   ...                          ...        ...
# 8919   Volvo   S70  1998             regular unleaded      168.0
# 11600  Volvo  XC60  2017             regular unleaded      240.0
# 11604  Volvo  XC60  2017             regular unleaded      240.0
# 11601  Volvo  XC60  2017             regular unleaded      302.0
# 11603  Volvo  XC60  2017             regular unleaded      302.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 8536                6.0         AUTOMATIC    all wheel drive              4.0
# ...

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (11199, 16)

# %%
df=df.drop("Market Category",axis=1)

# %%
int_col=df.select_dtypes("int")
cat_col=df.select_dtypes("O").columns
for col in cat_col:
    print(df[col].value_counts())
    print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
# Out:
# Make
# Chevrolet        1083
# Ford              825
# Toyota            719
# Volkswagen        568
# Nissan            551
# Dodge             529
# GMC               482
# Honda             433
# Mazda             412
# Cadillac          396
# Suzuki            342
# Mercedes-Benz     341
# Infiniti          328
# BMW               324
# Audi              321
# Volvo             266
# Hyundai           259
# Acura             246
# Subaru            239
# Kia               229
# Mitsubishi        208
# Lexus             202
# Buick             190
# Chrysler          187
# Pontiac           181
# Lincoln           160
# Land Rover        139
# Porsche           136
# Oldsmobile        132
# Saab              109
# Aston Martin       91
# Bentley            74
# Plymouth           71
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           55
# Lamborghini        52
# Rolls-Royce        31
# Lotus              28
# Tesla              18
# ...

# %%
df.describe().T
# Out:
#                     count          mean           std     min      25%  \
# Year              11199.0   2010.714528      7.228211  1990.0   2007.0
# Engine HP         11130.0    253.388859    110.150938    55.0    172.0
# Engine Cylinders  11169.0      5.665950      1.797021     0.0      4.0
# Number of Doors   11193.0      3.454123      0.872946     2.0      2.0
# highway MPG       11199.0     26.610590      8.977641    12.0     22.0
# city mpg          11199.0     19.731851      9.177555     7.0     16.0
# Popularity        11199.0   1558.483347   1445.668872     2.0    549.0
# MSRP              11199.0  41925.927136  61535.047817  2000.0  21599.5
#
#                       50%      75%        max
# Year               2015.0   2016.0     2017.0
# Engine HP           239.0    303.0     1001.0
# Engine Cylinders      6.0      6.0       16.0
# Number of Doors       4.0      4.0        4.0
# highway MPG          25.0     30.0      354.0
# city mpg             18.0     22.0      137.0
# ...

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %%
df.groupby(["Make","Engine HP","Year"],as_index=False).agg({"MSRP":"mean"}).tail(25)
# Out:
#        Make  Engine HP  Year          MSRP
# 2964  Volvo      235.0  2010  35775.000000
# 2965  Volvo      236.0  1998   2232.000000
# 2966  Volvo      236.0  1999   2382.000000
# 2967  Volvo      236.0  2000   2608.000000
# 2968  Volvo      240.0  1995   2000.000000
# 2969  Volvo      240.0  1996   2000.000000
# 2970  Volvo      240.0  1997   2045.500000
# 2971  Volvo      240.0  2014  39200.000000
# 2972  Volvo      240.0  2015  38495.238095
# 2973  Volvo      240.0  2016  40689.705882
# 2974  Volvo      240.0  2017  39975.000000
# 2975  Volvo      250.0  2015  39450.000000
# 2976  Volvo      250.0  2016  43646.666667
# 2977  Volvo      250.0  2017  48575.000000
# 2978  Volvo      300.0  2014  42450.000000
# 2979  Volvo      300.0  2015  44068.181818
# 2980  Volvo      300.0  2016  44850.000000
# 2981  Volvo      302.0  2015  42083.333333
# 2982  Volvo      302.0  2016  45604.166667
# 2983  Volvo      302.0  2017  48425.000000
# 2984  Volvo      316.0  2016  56175.000000
# ...

# %%
plt.figure(figsize = (12,10))
plt.title("Correlation between different features of the dataset", fontsize = 18, fontweight = 'bold')
sns.heatmap(int_col.corr(), cmap = 'Greens_r', annot = True)
plt.xticks(fontsize=12, rotation = 90)
plt.yticks(fontsize=12, rotation = 90)
plt.legend(fontsize=12)
# Out:
# /var/folders/50/8zx_6x713jv2x3s7tf2tpsqr0000gn/T/ipykernel_33728/3982116623.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=12)

# %%
sns.histplot(df,x="MSRP",)
# Out:
# <Axes: xlabel='MSRP', ylabel='Count'>

# %%
sns.displot(df,x="MSRP",)

# %%
plt.boxplot(x=df["MSRP"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1141bdee0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1141be3f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x113dad040>],
#  'medians': [<matplotlib.lines.Line2D at 0x1141be9c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1141bec60>],
#  'means': []}

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %%
df.loc[df["Engine HP"] < 150, "Engine_HP_cat"] = "Low HP"
df.loc[(df["Engine HP"] >= 150) & (df["Engine HP"] < 250), "Engine_HP_cat"] = "Moderate HP"
df.loc[(df["Engine HP"] >= 250) & (df["Engine HP"] <= 400), "Engine_HP_cat"] = "High HP"
df.loc[df["Engine HP"] > 400, "Engine_HP_cat"] = "Supercharged"

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP  \
# ...
