# %%
import os 
import pandas as pd
from pandasql import sqldf

# %%
a=os.getcwd()

# %%
path=os.path.join(a,"data","dvdrental")

# %%
os.listdir(path)
# Out:
# ['staff.csv',
#  'actor.csv',
#  'film.csv',
#  'film_category.csv',
#  'customer.csv',
#  'language.csv',
#  'film_actor.csv',
#  'address.csv',
#  'city.csv',
#  'country.csv',
#  'payment.csv',
#  'category.csv',
#  'rental.csv',
#  'store.csv',
#  'inventory.csv']

# %%
df=pd.read_csv("/Users/firatyalin/Desktop/GIT/Today/eurotech_ds/data/dvdrental/film.csv",sep=";")
actor=pd.read_csv("/Users/firatyalin/Desktop/GIT/Today/eurotech_ds/data/dvdrental/actor.csv")

# %%
actor.head()
# Out:
#    actor_id first_name     last_name             last_update
# 0         1   Penelope       Guiness  2013-05-26 14:47:57.62
# 1         2       Nick      Wahlberg  2013-05-26 14:47:57.62
# 2         3         Ed         Chase  2013-05-26 14:47:57.62
# 3         4   Jennifer         Davis  2013-05-26 14:47:57.62
# 4         5     Johnny  Lollobrigida  2013-05-26 14:47:57.62

# %%
df.head()
# Out:
#    film_id              title  \
# 0      133    Chamber Italian
# 1      384   Grosse Wonderful
# 2        8    Airport Pollock
# 3       98  Bright Encounters
# 4        1   Academy Dinosaur
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
# 1  A Epic Drama of a Cat And a Explorer who must ...          2006
# 2  A Epic Tale of a Moose And a Girl who must Con...          2006
# 3  A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4  A Epic Drama of a Feminist And a Mad Scientist...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         4.99     117             14.99  NC-17
# 1            1                5         4.99      49             19.99      R
# 2            1                6         4.99      54             15.99      R
# 3            1                4         4.99      73             12.99  PG-13
# 4            1                6         0.99      86             20.99     PG
#
#                last_update                    special_features  \
# 0  2013-05-26 14:50:58.951                          {Trailers}
# 1  2013-05-26 14:50:58.951                 {Behind the Scenes}
# 2  2013-05-26 14:50:58.951                          {Trailers}
# 3  2013-05-26 14:50:58.951                          {Trailers}
# 4  2013-05-26 14:50:58.951  {Deleted Scenes,Behind the Scenes}
#
#                                             fulltext
# 0  chamber:1 fate:4 husband:11 italian:2 monkey:1...
# 1  australia:18 cat:8 drama:5 epic:4 explor:11 gr...
# 2  airport:1 ancient:18 confront:14 epic:4 girl:1...
# 3  boat:20 bright:1 conquer:14 encount:2 fate:4 f...
# 4  academi:1 battl:15 canadian:20 dinosaur:2 dram...

# %%
q = """
        SELECT * 
        FROM df
        LIMIT 5;
    """

sqldf(q)
# Out:
#    film_id              title  \
# 0      133    Chamber Italian
# 1      384   Grosse Wonderful
# 2        8    Airport Pollock
# 3       98  Bright Encounters
# 4        1   Academy Dinosaur
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
# 1  A Epic Drama of a Cat And a Explorer who must ...          2006
# 2  A Epic Tale of a Moose And a Girl who must Con...          2006
# 3  A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4  A Epic Drama of a Feminist And a Mad Scientist...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         4.99     117             14.99  NC-17
# 1            1                5         4.99      49             19.99      R
# 2            1                6         4.99      54             15.99      R
# 3            1                4         4.99      73             12.99  PG-13
# 4            1                6         0.99      86             20.99     PG
#
#                last_update                    special_features  \
# 0  2013-05-26 14:50:58.951                          {Trailers}
# 1  2013-05-26 14:50:58.951                 {Behind the Scenes}
# 2  2013-05-26 14:50:58.951                          {Trailers}
# 3  2013-05-26 14:50:58.951                          {Trailers}
# 4  2013-05-26 14:50:58.951  {Deleted Scenes,Behind the Scenes}
#
#                                             fulltext
# 0  chamber:1 fate:4 husband:11 italian:2 monkey:1...
# 1  australia:18 cat:8 drama:5 epic:4 explor:11 gr...
# 2  airport:1 ancient:18 confront:14 epic:4 girl:1...
# 3  boat:20 bright:1 conquer:14 encount:2 fate:4 f...
# 4  academi:1 battl:15 canadian:20 dinosaur:2 dram...

# %%
df.iloc[25:45,1:3]
# Out:
#                           title  \
# 25            Amistad Midsummer
# 26         Anaconda Confessions
# 27             Analyze Hoosiers
# 28                  Angels Life
# 29               Annie Identity
# 30              Anonymous Human
# 31                  Anthem Luke
# 32           Antitrust Tomatoes
# 33            Anything Savannah
# 34                Apache Divine
# 35         Apocalypse Flamingos
# 36                  Apollo Teen
# 37                 Arabia Dogma
# 38  Arachnophobia Rollercoaster
# 39               Argonauts Town
# 40                 Arizona Bang
# 41                Ark Ridgemont
# 42              Armageddon Lost
# 43             Army Flintstones
# 44         Arsenic Independence
#
#                                           description
# 25  A Emotional Character Study of a Dentist And a...
# 26  A Lacklusture Display of a Dentist And a Denti...
# 27  A Thoughtful Display of a Explorer And a Pastr...
# 28  A Thoughtful Display of a Woman And a Astronau...
# 29  A Amazing Panorama of a Pastry Chef And a Boat...
# 30  A Amazing Reflection of a Database Administrat...
# 31  A Touching Panorama of a Waitress And a Woman ...
# 32  A Fateful Yarn of a Womanizer And a Feminist w...
# 33  A Epic Story of a Pastry Chef And a Woman who ...
# 34  A Awe-Inspiring Reflection of a Pastry Chef An...
# 35  A Astounding Story of a Dog And a Squirrel who...
# 36  A Action-Packed Reflection of a Crocodile And ...
# 37  A Touching Epistle of a Madman And a Mad Cow w...
# 38  A Action-Packed Reflection of a Pastry Chef An...
# 39  A Emotional Epistle of a Forensic Psychologist...
# 40  A Brilliant Panorama of a Mad Scientist And a ...
# 41  A Beautiful Yarn of a Pioneer And a Monkey who...
# 42  A Fast-Paced Tale of a Boat And a Teacher who ...
# 43  A Boring Saga of a Database Administrator And ...
# 44  A Fanciful Documentary of a Mad Cow And a Woma...

# %%
df.loc[25:45,"title"]
# Out:
# 25              Amistad Midsummer
# 26           Anaconda Confessions
# 27               Analyze Hoosiers
# 28                    Angels Life
# 29                 Annie Identity
# 30                Anonymous Human
# 31                    Anthem Luke
# 32             Antitrust Tomatoes
# 33              Anything Savannah
# 34                  Apache Divine
# 35           Apocalypse Flamingos
# 36                    Apollo Teen
# 37                   Arabia Dogma
# 38    Arachnophobia Rollercoaster
# 39                 Argonauts Town
# 40                   Arizona Bang
# 41                  Ark Ridgemont
# 42                Armageddon Lost
# 43               Army Flintstones
# 44           Arsenic Independence
# 45             Artist Coldblooded
# Name: title, dtype: object

# %%
q = """
        SELECT * 
        FROM df
        LIMIT 5
        offset 25
    """

sqldf(q)
# Out:
#    film_id                 title  \
# 0       22     Amistad Midsummer
# 1       23  Anaconda Confessions
# 2       24      Analyze Hoosiers
# 3       25           Angels Life
# 4       26        Annie Identity
#
#                                          description  release_year  \
# 0  A Emotional Character Study of a Dentist And a...          2006
# 1  A Lacklusture Display of a Dentist And a Denti...          2006
# 2  A Thoughtful Display of a Explorer And a Pastr...          2006
# 3  A Thoughtful Display of a Woman And a Astronau...          2006
# 4  A Amazing Panorama of a Pastry Chef And a Boat...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                6         2.99      85             10.99      G
# 1            1                3         0.99      92              9.99      R
# 2            1                6         2.99     181             19.99      R
# 3            1                3         2.99      74             15.99      G
# 4            1                3         0.99      86             15.99      G
#
#                last_update                  special_features  \
# 0  2013-05-26 14:50:58.951  {Commentaries,Behind the Scenes}
# 1  2013-05-26 14:50:58.951         {Trailers,Deleted Scenes}
# 2  2013-05-26 14:50:58.951      {Trailers,Behind the Scenes}
# 3  2013-05-26 14:50:58.951                        {Trailers}
# 4  2013-05-26 14:50:58.951     {Commentaries,Deleted Scenes}
#
#                                             fulltext
# 0  amistad:1 california:20 charact:5 crocodil:12 ...
# 1  anaconda:1 australia:18 confess:2 dentist:8,11...
# 2  analyz:1 chef:12 desert:21 display:5 explor:8 ...
# 3  angel:1 astronaut:11 battl:14 berlin:18 displa...
# 4  abandon:20 amaz:4 amus:21 anni:1 boat:12 chef:...

# %%
df.rename(columns={"rental_duration":"duration"},inplace=True)

# %%
actor["Fullname"]=actor["first_name"]+" "+actor["last_name"]

# %%
actor.head()
# Out:
#    actor_id first_name     last_name             last_update  \
# 0         1   Penelope       Guiness  2013-05-26 14:47:57.62
# 1         2       Nick      Wahlberg  2013-05-26 14:47:57.62
# 2         3         Ed         Chase  2013-05-26 14:47:57.62
# 3         4   Jennifer         Davis  2013-05-26 14:47:57.62
# 4         5     Johnny  Lollobrigida  2013-05-26 14:47:57.62
#
#               Fullname
# 0     Penelope Guiness
# 1        Nick Wahlberg
# 2             Ed Chase
# 3       Jennifer Davis
# 4  Johnny Lollobrigida

# %%
q = """
        SELECT first_name || ' ' || last_name as fullname
        FROM actor
        LIMIT 5
    """

sqldf(q)
# Out:
#               fullname
# 0     Penelope Guiness
# 1        Nick Wahlberg
# 2             Ed Chase
# 3       Jennifer Davis
# 4  Johnny Lollobrigida

# %%
df.sort_values(by="replacement_cost",ascending=False)
# Out:
#      film_id                 title  \
# 993      994         Wyoming Storm
# 474      475          Japanese Run
# 479      480       Jeepers Wedding
# 37        34          Arabia Dogma
# 943      944          Virgin Daisy
# ..       ...                   ...
# 914      915          Truman Crazy
# 500      501         Kissing Dolls
# 930      931   Valentine Vanishing
# 26        23  Anaconda Confessions
# 952      953            Wait Cider
#
#                                            description  release_year  \
# 993  A Awe-Inspiring Panorama of a Robot And a Boat...          2006
# 474  A Awe-Inspiring Epistle of a Feminist And a Gi...          2006
# 479  A Astounding Display of a Composer And a Dog w...          2006
# 37   A Touching Epistle of a Madman And a Mad Cow w...          2006
# 943  A Awe-Inspiring Documentary of a Robot And a M...          2006
# ..                                                 ...           ...
# 914  A Thrilling Epistle of a Moose And a Boy who m...          2006
# 500  A Insightful Reflection of a Pioneer And a Tea...          2006
# 930  A Thrilling Display of a Husband And a Butler ...          2006
# 26   A Lacklusture Display of a Dentist And a Denti...          2006
# 952  A Intrepid Epistle of a Woman And a Forensic P...          2006
#
#      language_id  duration  rental_rate  length  replacement_cost rating  \
# 993            1         6         4.99     100             29.99  PG-13
# 474            1         6         0.99     135             29.99      G
# 479            1         3         2.99      84             29.99      R
# 37             1         6         0.99      62             29.99  NC-17
# 943            1         6         4.99     179             29.99  PG-13
# ..           ...       ...          ...     ...               ...    ...
# 914            1         7         4.99      92              9.99      G
# 500            1         3         4.99     141              9.99      R
# 930            1         7         0.99      48              9.99  PG-13
# 26             1         3         0.99      92              9.99      R
# 952            1         3         0.99     112              9.99  PG-13
#
#                  last_update                        special_features  \
# 993  2013-05-26 14:50:58.951                        {Deleted Scenes}
# 474  2013-05-26 14:50:58.951                        {Deleted Scenes}
# 479  2013-05-26 14:50:58.951  {Trailers,Commentaries,Deleted Scenes}
# 37   2013-05-26 14:50:58.951           {Commentaries,Deleted Scenes}
# 943  2013-05-26 14:50:58.951            {Trailers,Behind the Scenes}
# ..                       ...                                     ...
# 914  2013-05-26 14:50:58.951                 {Trailers,Commentaries}
# 500  2013-05-26 14:50:58.951                              {Trailers}
# 930  2013-05-26 14:50:58.951            {Trailers,Behind the Scenes}
# 26   2013-05-26 14:50:58.951               {Trailers,Deleted Scenes}
# 952  2013-05-26 14:50:58.951                              {Trailers}
#
#                                               fulltext
# 993  awe:5 awe-inspir:4 boat:13,23 feminist:18 insp...
# 474  awe:5 awe-inspir:4 epistl:7 feminist:10 girl:1...
# 479  astound:4 chef:17 compos:8 display:5 dog:11 ge...
# 37   arabia:1 cow:12 defeat:15 dogma:2 epistl:5 mad...
# 943  administr:20 awe:5 awe-inspir:4 daisi:2 databa...
# ..                                                 ...
# 914  administr:17 boy:11 crazi:2 databas:16 epistl:...
# 500  build:14 compos:16 doll:2 first:19 insight:4 k...
# 930  butler:11 california:19 chef:17 display:5 husb...
# 26   anaconda:1 australia:18 confess:2 dentist:8,11...
# 952  astronaut:17 cider:2 epistl:5 forens:11 intrep...
#
# [1000 rows x 13 columns]

# %%
df.sort_values(by="rating",ascending=False)
# Out:
#      film_id             title  \
# 500      501     Kissing Dolls
# 885      884   Terminator Club
# 764      765       Saturn Name
# 894      895  Tomorrow Hustler
# 448      447      Ice Crossing
# ..       ...               ...
# 879      878       Teen Apollo
# 218      217        Dazed Punk
# 217      216    Day Unfaithful
# 214      212    Darn Forrester
# 208      206     Dancing Fever
#
#                                            description  release_year  \
# 500  A Insightful Reflection of a Pioneer And a Tea...          2006
# 885  A Touching Story of a Crocodile And a Girl who...          2006
# 764  A Fateful Epistle of a Butler And a Boy who mu...          2006
# 894  A Thoughtful Story of a Moose And a Husband wh...          2006
# 448  A Fast-Paced Tale of a Butler And a Moose who ...          2006
# ..                                                 ...           ...
# 879  A Awe-Inspiring Drama of a Dog And a Man who m...          2006
# 218  A Action-Packed Story of a Pioneer And a Techn...          2006
# 217  A Stunning Documentary of a Composer And a Mad...          2006
# 214  A Fateful Story of a A Shark And a Explorer wh...          2006
# 208  A Stunning Story of a Explorer And a Forensic ...          2006
#
#      language_id  duration  rental_rate  length  replacement_cost rating  \
# 500            1         3         4.99     141              9.99      R
# 885            1         5         4.99      88             11.99      R
# 764            1         7         4.99     182             18.99      R
# 894            1         3         2.99     142             21.99      R
# 448            1         5         2.99     131             28.99      R
# ..           ...       ...          ...     ...               ...    ...
# 879            1         3         4.99      74             25.99      G
# 218            1         6         4.99     120             20.99      G
# 217            1         3         4.99     113             16.99      G
# 214            1         7         4.99     185             14.99      G
# 208            1         6         0.99     144             25.99      G
#
#                  last_update  \
# 500  2013-05-26 14:50:58.951
# 885  2013-05-26 14:50:58.951
# 764  2013-05-26 14:50:58.951
# 894  2013-05-26 14:50:58.951
# 448  2013-05-26 14:50:58.951
# ..                       ...
# 879  2013-05-26 14:50:58.951
# 218  2013-05-26 14:50:58.951
# 217  2013-05-26 14:50:58.951
# 214  2013-05-26 14:50:58.951
# 208  2013-05-26 14:50:58.951
#
#                                       special_features  \
# 500                                         {Trailers}
# 885        {Trailers,Deleted Scenes,Behind the Scenes}
# 764  {Trailers,Commentaries,Deleted Scenes,Behind t...
# 894                                     {Commentaries}
# 448                                   {Deleted Scenes}
# ..                                                 ...
# 879        {Trailers,Deleted Scenes,Behind the Scenes}
# 218                      {Commentaries,Deleted Scenes}
# 217  {Trailers,Commentaries,Deleted Scenes,Behind t...
# 214                                   {Deleted Scenes}
# 208                   {Commentaries,Behind the Scenes}
#
#                                               fulltext
# 500  build:14 compos:16 doll:2 first:19 insight:4 k...
# 885  club:2 crocodil:8 girl:11 gulf:19 man:16 mexic...
# 764  berlin:18 boy:11 butler:8 epistl:5 fate:4 must...
# 894  agent:17 desert:21 face:14 husband:11 hustler:...
# 448  butler:10 cross:2 fast:5 fast-pac:4 ice:1 manh...
# ..                                                 ...
# 879  apollo:2 awe:5 awe-inspir:4 dog:10 drama:7 esc...
# 218  abandon:23 action:5 action-pack:4 amus:24 daze...
# 217  boat:23 compos:8 day:1 documentari:5 find:15 m...
# 214  boat:22 darn:1 explor:12 fate:4 forrest:2 jet:...
# 208  crocodil:17 danc:1 explor:8 face:15 fever:2 fo...
#
# [1000 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['film_id', 'title', 'description', 'release_year', 'language_id',
#        'duration', 'rental_rate', 'length', 'replacement_cost', 'rating',
#        'last_update', 'special_features', 'fulltext'],
#       dtype='object')

# %%
df[(df["rating"]!="PG-13") | (df["length"]>=50)]
# Out:
#      film_id              title  \
# 0        133    Chamber Italian
# 1        384   Grosse Wonderful
# 2          8    Airport Pollock
# 3         98  Bright Encounters
# 4          1   Academy Dinosaur
# ..       ...                ...
# 995      996     Young Language
# 996      997         Youth Kick
# 997      998       Zhivago Core
# 998      999  Zoolander Fiction
# 999     1000          Zorro Ark
#
#                                            description  release_year  \
# 0    A Fateful Reflection of a Moose And a Husband ...          2006
# 1    A Epic Drama of a Cat And a Explorer who must ...          2006
# 2    A Epic Tale of a Moose And a Girl who must Con...          2006
# 3    A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4    A Epic Drama of a Feminist And a Mad Scientist...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# 996  A Touching Drama of a Teacher And a Cat who mu...          2006
# 997  A Fateful Yarn of a Composer And a Man who mus...          2006
# 998  A Fateful Reflection of a Waitress And a Boat ...          2006
# 999  A Intrepid Panorama of a Mad Scientist And a B...          2006
#
#      language_id  duration  rental_rate  length  replacement_cost rating  \
# 0              1         7         4.99     117             14.99  NC-17
# 1              1         5         4.99      49             19.99      R
# 2              1         6         4.99      54             15.99      R
# 3              1         4         4.99      73             12.99  PG-13
# 4              1         6         0.99      86             20.99     PG
# ..           ...       ...          ...     ...               ...    ...
# 995            1         6         0.99     183              9.99      G
# 996            1         4         0.99     179             14.99  NC-17
# 997            1         6         0.99     105             10.99  NC-17
# 998            1         5         2.99     101             28.99      R
# 999            1         3         4.99      50             18.99  NC-17
#
#                  last_update                           special_features  \
# 0    2013-05-26 14:50:58.951                                 {Trailers}
# 1    2013-05-26 14:50:58.951                        {Behind the Scenes}
# 2    2013-05-26 14:50:58.951                                 {Trailers}
# 3    2013-05-26 14:50:58.951                                 {Trailers}
# 4    2013-05-26 14:50:58.951         {Deleted Scenes,Behind the Scenes}
# ..                       ...                                        ...
# 995  2013-05-26 14:50:58.951               {Trailers,Behind the Scenes}
# 996  2013-05-26 14:50:58.951               {Trailers,Behind the Scenes}
# 997  2013-05-26 14:50:58.951                           {Deleted Scenes}
# 998  2013-05-26 14:50:58.951                  {Trailers,Deleted Scenes}
# 999  2013-05-26 14:50:58.951  {Trailers,Commentaries,Behind the Scenes}
#
#                                               fulltext
# 0    chamber:1 fate:4 husband:11 italian:2 monkey:1...
# 1    australia:18 cat:8 drama:5 epic:4 explor:11 gr...
# 2    airport:1 ancient:18 confront:14 epic:4 girl:1...
# 3    boat:20 bright:1 conquer:14 encount:2 fate:4 f...
# 4    academi:1 battl:15 canadian:20 dinosaur:2 dram...
# ..                                                 ...
# 995  administr:12 boat:8 boy:17 databas:11 first:20...
# 996  boat:22 cat:11 challeng:14 drama:5 kick:2 must...
# 997  boy:16 canadian:19 compos:8 core:2 face:14 fat...
# 998  ancient:19 boat:11 china:20 discov:14 fate:4 f...
# 999  ark:2 boy:12,17 intrepid:4 mad:8 monasteri:20 ...
#
# [992 rows x 13 columns]

# %%
a=['PG', 'PG-13', 'NC-17']

# %%
df[df["rating"].isin(a)]
# Out:
#      film_id              title  \
# 0        133    Chamber Italian
# 3         98  Bright Encounters
# 4          1   Academy Dinosaur
# 6          3   Adaptation Holes
# 9          6       Agent Truman
# ..       ...                ...
# 992      993     Wrong Behavior
# 993      994      Wyoming Storm
# 996      997         Youth Kick
# 997      998       Zhivago Core
# 999     1000          Zorro Ark
#
#                                            description  release_year  \
# 0    A Fateful Reflection of a Moose And a Husband ...          2006
# 3    A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 6    A Astounding Reflection of a Lumberjack And a ...          2006
# 9    A Intrepid Panorama of a Robot And a Boy who m...          2006
# ..                                                 ...           ...
# 992  A Emotional Saga of a Crocodile And a Sumo Wre...          2006
# 993  A Awe-Inspiring Panorama of a Robot And a Boat...          2006
# 996  A Touching Drama of a Teacher And a Cat who mu...          2006
# 997  A Fateful Yarn of a Composer And a Man who mus...          2006
# 999  A Intrepid Panorama of a Mad Scientist And a B...          2006
#
#      language_id  duration  rental_rate  length  replacement_cost rating  \
# 0              1         7         4.99     117             14.99  NC-17
# 3              1         4         4.99      73             12.99  PG-13
# 4              1         6         0.99      86             20.99     PG
# 6              1         7         2.99      50             18.99  NC-17
# 9              1         3         2.99     169             17.99     PG
# ..           ...       ...          ...     ...               ...    ...
# 992            1         6         2.99     178             10.99  PG-13
# 993            1         6         4.99     100             29.99  PG-13
# 996            1         4         0.99     179             14.99  NC-17
# 997            1         6         0.99     105             10.99  NC-17
# 999            1         3         4.99      50             18.99  NC-17
#
#                  last_update                           special_features  \
# 0    2013-05-26 14:50:58.951                                 {Trailers}
# 3    2013-05-26 14:50:58.951                                 {Trailers}
# 4    2013-05-26 14:50:58.951         {Deleted Scenes,Behind the Scenes}
# 6    2013-05-26 14:50:58.951                  {Trailers,Deleted Scenes}
# 9    2013-05-26 14:50:58.951                           {Deleted Scenes}
# ..                       ...                                        ...
# 992  2013-05-26 14:50:58.951               {Trailers,Behind the Scenes}
# 993  2013-05-26 14:50:58.951                           {Deleted Scenes}
# 996  2013-05-26 14:50:58.951               {Trailers,Behind the Scenes}
# 997  2013-05-26 14:50:58.951                           {Deleted Scenes}
# 999  2013-05-26 14:50:58.951  {Trailers,Commentaries,Behind the Scenes}
#
#                                               fulltext
# 0    chamber:1 fate:4 husband:11 italian:2 monkey:1...
# 3    boat:20 bright:1 conquer:14 encount:2 fate:4 f...
# 4    academi:1 battl:15 canadian:20 dinosaur:2 dram...
# 6    adapt:1 astound:4 baloon:19 car:11 factori:20 ...
# 9    agent:1 ancient:19 boy:11 china:20 escap:14 in...
# ..                                                 ...
# 992  behavior:2 cow:18 crocodil:8 discov:15 emot:4 ...
# 993  awe:5 awe-inspir:4 boat:13,23 feminist:18 insp...
# 996  boat:22 cat:11 challeng:14 drama:5 kick:2 must...
# 997  boy:16 canadian:19 compos:8 core:2 face:14 fat...
# 999  ark:2 boy:12,17 intrepid:4 mad:8 monasteri:20 ...
#
# [627 rows x 13 columns]

# %%
df["duration"].value_counts(dropna=False)
# Out:
# duration
# 6    212
# 3    203
# 4    203
# 7    191
# 5    191
# Name: count, dtype: int64

# %%
df.loc[df['title'].str.match(r'..m.*')].head()
# Out:
#      film_id             title  \
# 42        39   Armageddon Lost
# 43        40  Army Flintstones
# 118      114  Camelot Vacation
# 119      115   Campus Remember
# 170      167         Coma Head
#
#                                            description  release_year  \
# 42   A Fast-Paced Tale of a Boat And a Teacher who ...          2006
# 43   A Boring Saga of a Database Administrator And ...          2006
# 118  A Touching Character Study of a Woman And a Wa...          2006
# 119  A Astounding Drama of a Crocodile And a Mad Co...          2006
# 170  A Awe-Inspiring Drama of a Boy And a Frisbee w...          2006
#
#      language_id  duration  rental_rate  length  replacement_cost rating  \
# 42             1         5         0.99      99             10.99      G
# 43             1         4         0.99     148             22.99      R
# 118            1         3         0.99      61             26.99  NC-17
# 119            1         5         2.99     167             27.99      R
# 170            1         6         4.99     109             10.99  NC-17
#
#                  last_update  \
# 42   2013-05-26 14:50:58.951
# 43   2013-05-26 14:50:58.951
# 118  2013-05-26 14:50:58.951
# 119  2013-05-26 14:50:58.951
# 170  2013-05-26 14:50:58.951
#
#                                       special_features  \
# 42                                          {Trailers}
# 43                             {Trailers,Commentaries}
# 118  {Trailers,Commentaries,Deleted Scenes,Behind t...
# 119                                {Behind the Scenes}
# 170                                     {Commentaries}
#
#                                               fulltext
# 42   abandon:21 armageddon:1 boat:10 compos:18 fast...
# 43   administr:9 armi:1 battl:15 bore:4 databas:8 f...
# 118  battl:15 camelot:1 charact:5 chef:18 convent:2...
# 119  astound:4 boat:21 build:15 campus:1 cow:12 cro...
# 170  awe:5 awe-inspir:4 boy:10 california:21 chef:1...

# %% [markdown]
# Average rental duration and max of replacement cost for films in each rating category

# %%
df.groupby("rating",as_index=False).agg({"duration":"mean","replacement_cost":"max"})
# Out:
#   rating  duration  replacement_cost
# 0      G  4.837079             29.99
# 1  NC-17  5.142857             29.99
# 2     PG  5.082474             29.99
# 3  PG-13  5.053812             29.99
# 4      R  4.774359             29.99
