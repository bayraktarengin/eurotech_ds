# %%
#To install the library
# !pip install pandasql

# %%
import pandas as pd
from pandasql import sqldf

# %%
nyc_data_sep = pd.read_csv("./nyc_sample_data_for_sql_sep_2015.csv")
nyc_data_oct = pd.read_csv("./nyc_sample_data_for_sql_oct_2015.csv")

# %%
nyc_data_sep.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'Lpep_dropoff_datetime',
#        'Store_and_fwd_flag', 'RateCodeID', 'Pickup_longitude',
#        'Pickup_latitude', 'Dropoff_longitude', 'Dropoff_latitude',
#        'Passenger_count', 'Trip_distance', 'Fare_amount', 'Extra', 'MTA_tax',
#        'Tip_amount', 'Tolls_amount', 'Ehail_fee', 'improvement_surcharge',
#        'Total_amount', 'Payment_type', 'Trip_type ', 'lpep_pickup_hour',
#        'lpep_pickup_day_of_week', 'trip_id', 'driver_id'],
#       dtype='object')

# %%
nyc_data_sep.head(5)
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-09-01 01:17:11   2015-09-01 01:23:01                  N
# 1         2  2015-09-01 02:01:29   2015-09-01 02:22:58                  N
# 2         2  2015-09-01 04:28:56   2015-09-01 04:28:58                  N
# 3         2  2015-09-01 06:56:55   2015-09-01 06:59:09                  N
# 4         2  2015-09-01 07:54:44   2015-09-01 07:57:07                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.830284        40.759506         -73.813698
# 1           1        -73.955322        40.720055         -73.906677
# 2           5          0.000000         0.000000         -73.939354
# 3           1        -73.914764        40.763802         -73.921127
# 4           1        -73.894241        40.864166         -73.897781
#
#    Dropoff_latitude  Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 0         40.751537                2  ...           0.0        NaN
# 1         40.684845                1  ...           0.0        NaN
# 2         40.788391                1  ...           0.0        NaN
# 3         40.766788                1  ...           0.0        NaN
# 4         40.870739                1  ...           0.0        NaN
#
#    improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                    0.3          7.80             2         1.0
# 1                    0.3         22.56             1         1.0
# 2                    0.0         15.00             1         2.0
# 3                    0.3          5.38             1         1.0
# 4                    0.3          6.24             1         1.0
#
#    lpep_pickup_hour  lpep_pickup_day_of_week  trip_id  driver_id
# 0                 1                  Tuesday        1          2
# 1                 2                  Tuesday        2          2
# 2                 4                  Tuesday        3          3
# 3                 6                  Tuesday        4          5
# 4                 7                  Tuesday        5          2
#
# [5 rows x 25 columns]

# %%
## Test query
# Just put your query into the value q and put this as a parameter into sqldf function.
q = """
        SELECT * 
        FROM nyc_data_sep
        LIMIT 5;
    """

sqldf(q)
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-09-01 01:17:11   2015-09-01 01:23:01                  N
# 1         2  2015-09-01 02:01:29   2015-09-01 02:22:58                  N
# 2         2  2015-09-01 04:28:56   2015-09-01 04:28:58                  N
# 3         2  2015-09-01 06:56:55   2015-09-01 06:59:09                  N
# 4         2  2015-09-01 07:54:44   2015-09-01 07:57:07                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.830284        40.759506         -73.813698
# 1           1        -73.955322        40.720055         -73.906677
# 2           5          0.000000         0.000000         -73.939354
# 3           1        -73.914764        40.763802         -73.921127
# 4           1        -73.894241        40.864166         -73.897781
#
#    Dropoff_latitude  Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 0         40.751537                2  ...           0.0       None
# 1         40.684845                1  ...           0.0       None
# 2         40.788391                1  ...           0.0       None
# 3         40.766788                1  ...           0.0       None
# 4         40.870739                1  ...           0.0       None
#
#    improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                    0.3          7.80             2         1.0
# 1                    0.3         22.56             1         1.0
# 2                    0.0         15.00             1         2.0
# 3                    0.3          5.38             1         1.0
# 4                    0.3          6.24             1         1.0
#
#   lpep_pickup_hour  lpep_pickup_day_of_week  trip_id  driver_id
# 0                1                  Tuesday        1          2
# 1                2                  Tuesday        2          2
# 2                4                  Tuesday        3          3
# 3                6                  Tuesday        4          5
# 4                7                  Tuesday        5          2
#
# [5 rows x 25 columns]

# %%
q = """
        SELECT VendorID,
        NULL as dami1,
        2 as dami2 
        FROM nyc_data_sep
        LIMIT 5;
    """

sqldf(q)
# Out:
#    VendorID dami1  dami2
# 0         2  None      2
# 1         2  None      2
# 2         2  None      2
# 3         2  None      2
# 4         2  None      2

# %%
#   1. Most expensive trip (total amount).

q = """
        SELECT * , MAX(Total_amount)
        FROM nyc_data_sep
        LIMIT 5;
    """

sqldf(q)
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-09-13 16:08:43   2015-09-13 16:53:13                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           3        -73.945396        40.719357         -74.177361
#
#    Dropoff_latitude  Passenger_count  ...  Ehail_fee  improvement_surcharge  \
# 0         40.695236                1  ...       None                    0.3
#
#    Total_amount  Payment_type  Trip_type   lpep_pickup_hour  \
# 0        136.36             1         1.0                16
#
#   lpep_pickup_day_of_week  trip_id  driver_id  MAX(Total_amount)
# 0                  Sunday      637          1             136.36
#
# [1 rows x 26 columns]

# %%
#   1. Most expensive trip (total amount).

q = """
        SELECT * 
        FROM nyc_data_sep
        order by Total_amount DESC
        LIMIT 1;
    """

sqldf(q)
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-09-13 16:08:43   2015-09-13 16:53:13                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           3        -73.945396        40.719357         -74.177361
#
#    Dropoff_latitude  Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 0         40.695236                1  ...         22.83       None
#
#    improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                    0.3        136.36             1         1.0
#
#   lpep_pickup_hour  lpep_pickup_day_of_week  trip_id  driver_id
# 0               16                   Sunday      637          1
#
# [1 rows x 25 columns]

# %%
#   1. Most expensive trip (total amount).

q = """
        SELECT * 
        FROM nyc_data_sep
        where Total_amount=136.36
    """

sqldf(q)
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-09-13 16:08:43   2015-09-13 16:53:13                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           3        -73.945396        40.719357         -74.177361
#
#    Dropoff_latitude  Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 0         40.695236                1  ...         22.83       None
#
#    improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                    0.3        136.36             1         1.0
#
#   lpep_pickup_hour  lpep_pickup_day_of_week  trip_id  driver_id
# 0               16                   Sunday      637          1
#
# [1 rows x 25 columns]

# %%
#   1. Most expensive trip (total amount).

q = """
        SELECT  MAX(Total_amount)
        FROM nyc_data_sep
    """

sqldf(q)
# Out:
#    MAX(Total_amount)
# 0             136.36

# %%
#   1. Most expensive trip (total amount).
# Subquery 

q = """
        SELECT * 
        FROM nyc_data_sep
        where Total_amount=(SELECT  MAX(Total_amount)
        FROM nyc_data_sep)
    """

sqldf(q)
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-09-13 16:08:43   2015-09-13 16:53:13                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           3        -73.945396        40.719357         -74.177361
#
#    Dropoff_latitude  Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 0         40.695236                1  ...         22.83       None
#
#    improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                    0.3        136.36             1         1.0
#
#   lpep_pickup_hour  lpep_pickup_day_of_week  trip_id  driver_id
# 0               16                   Sunday      637          1
#
# [1 rows x 25 columns]

# %%
#   1. Most expensive trip (total amount).
# Subquery 

q = """

        select Trip_distance from
        (SELECT * 
        FROM nyc_data_sep
        where Total_amount=(SELECT  MAX(Total_amount)
        FROM nyc_data_sep)) 
    """

sqldf(q)
# Out:
#    Trip_distance
# 0          27.67

# %%
nyc_data_sep.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'Lpep_dropoff_datetime',
#        'Store_and_fwd_flag', 'RateCodeID', 'Pickup_longitude',
#        'Pickup_latitude', 'Dropoff_longitude', 'Dropoff_latitude',
#        'Passenger_count', 'Trip_distance', 'Fare_amount', 'Extra', 'MTA_tax',
#        'Tip_amount', 'Tolls_amount', 'Ehail_fee', 'improvement_surcharge',
#        'Total_amount', 'Payment_type', 'Trip_type ', 'lpep_pickup_hour',
#        'lpep_pickup_day_of_week', 'trip_id', 'driver_id'],
#       dtype='object')

# %%
#   2. Most expensive trip per mile (total amount/mile).


q = """
        SELECT MAX(Total_amount/Trip_distance) as Max_exp
        FROM nyc_data_sep

    """

sqldf(q)
# Out:
#    Max_exp
# 0   5280.0

# %%
#   2. Most expensive trip per mile (total amount/mile).
# Subquery


q = """
        SELECT *
        FROM (select MAX(Total_amount/Trip_distance) from nyc_data_sep )

    """

sqldf(q)
# Out:
#    MAX(Total_amount/Trip_distance)
# 0                           5280.0

# %%
#   3. Most generous trip (highest tip).

q = """
        SELECT *
        FROM nyc_data_sep where Tip_amount= (select MAX(Tip_amount) from nyc_data_sep )

    """

sqldf(q)
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         1  2015-09-02 23:43:21   2015-09-02 23:44:04                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           5        -73.956963         40.66954         -73.955902
#
#    Dropoff_latitude  Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 0         40.668324                1  ...           0.0       None
#
#    improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                    0.0          45.8             1         2.0
#
#   lpep_pickup_hour  lpep_pickup_day_of_week  trip_id  driver_id
# 0               23                Wednesday       65          3
#
# [1 rows x 25 columns]

# %%
nyc_data_sep.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-09-01 01:17:11   2015-09-01 01:23:01                  N
# 1         2  2015-09-01 02:01:29   2015-09-01 02:22:58                  N
# 2         2  2015-09-01 04:28:56   2015-09-01 04:28:58                  N
# 3         2  2015-09-01 06:56:55   2015-09-01 06:59:09                  N
# 4         2  2015-09-01 07:54:44   2015-09-01 07:57:07                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.830284        40.759506         -73.813698
# 1           1        -73.955322        40.720055         -73.906677
# 2           5          0.000000         0.000000         -73.939354
# 3           1        -73.914764        40.763802         -73.921127
# 4           1        -73.894241        40.864166         -73.897781
#
#    Dropoff_latitude  Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 0         40.751537                2  ...           0.0        NaN
# 1         40.684845                1  ...           0.0        NaN
# 2         40.788391                1  ...           0.0        NaN
# 3         40.766788                1  ...           0.0        NaN
# 4         40.870739                1  ...           0.0        NaN
#
#    improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                    0.3          7.80             2         1.0
# 1                    0.3         22.56             1         1.0
# 2                    0.0         15.00             1         2.0
# 3                    0.3          5.38             1         1.0
# 4                    0.3          6.24             1         1.0
#
#    lpep_pickup_hour  lpep_pickup_day_of_week  trip_id  driver_id
# 0                 1                  Tuesday        1          2
# 1                 2                  Tuesday        2          2
# 2                 4                  Tuesday        3          3
# 3                 6                  Tuesday        4          5
# 4                 7                  Tuesday        5          2
#
# [5 rows x 25 columns]

# %%
#4. Longest trip duration.

q = """
        SELECT *,CAST(STRFTIME('%s',Lpep_dropoff_datetime) as integer) - CAST(STRFTIME('%s',lpep_pickup_datetime) as integer) as second
        FROM nyc_data_sep
        order by second DESC
        limit 1;


    """

sqldf(q)
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-09-18 23:45:38   2015-09-19 23:26:57                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.958389        40.713402          -73.93689
#
#    Dropoff_latitude  Passenger_count  ...  Ehail_fee  improvement_surcharge  \
# 0         40.722069                1  ...       None                    0.3
#
#    Total_amount  Payment_type  Trip_type   lpep_pickup_hour  \
# 0          11.3             2         1.0                23
#
#   lpep_pickup_day_of_week  trip_id  driver_id  second
# 0                  Friday      879          1   85279
#
# [1 rows x 26 columns]

# %%
#   5. Mean tip by hour

q = """
        SELECT STRFTIME('%H',Lpep_dropoff_datetime) as hour ,AVG (Tip_amount) as AVG_TIP
        FROM nyc_data_sep
        GROUP by hour
        order by 2 desc

    """

sqldf(q)
# Out:
#    hour   AVG_TIP
# 0    23  2.369767
# 1    10  1.506607
# 2    09  1.448493
# 3    21  1.425543
# 4    16  1.421831
# 5    18  1.395937
# 6    01  1.393621
# 7    00  1.368611
# 8    22  1.359036
# 9    17  1.319579
# 10   20  1.202333
# 11   14  1.186935
# 12   19  1.185000
# 13   13  1.168636
# 14   07  1.165455
# 15   08  1.097500
# 16   15  1.097015
# 17   04  0.940909
# 18   11  0.929153
# 19   02  0.884186
# 20   12  0.834828
# 21   03  0.834583
# 22   05  0.817500
# 23   06  0.782917

# %%
#   5. Mean tip by hour

# 0-8,8-16,16-24  ortalama vardiya bahsis rakamlari ????????

q = """
        SELECT STRFTIME('%H',Lpep_dropoff_datetime) as hour ,AVG (Tip_amount) as AVG_TIP
        FROM nyc_data_sep
        GROUP by hour
        order by 2 desc

    """

sqldf(q)
# Out:
#    hour   AVG_TIP
# 0    23  2.369767
# 1    10  1.506607
# 2    09  1.448493
# 3    21  1.425543
# 4    16  1.421831
# 5    18  1.395937
# 6    01  1.393621
# 7    00  1.368611
# 8    22  1.359036
# 9    17  1.319579
# 10   20  1.202333
# 11   14  1.186935
# 12   19  1.185000
# 13   13  1.168636
# 14   07  1.165455
# 15   08  1.097500
# 16   15  1.097015
# 17   04  0.940909
# 18   11  0.929153
# 19   02  0.884186
# 20   12  0.834828
# 21   03  0.834583
# 22   05  0.817500
# 23   06  0.782917

# %%
#7. Average total trip by day of week (Fortunately, we have day of week information. Otherwise, 
# we need to create a new date column without hours from date column. Then, we need to create "day of week" column, i.e Monday, Tuesday .. or 1, 2 .., 
# from that new date column. Total trip count should be found for each day, lastly average total trip should be calculated for each day).

q = """
        
        
        
        select lpep_pickup_day_of_week,avg(trip) from (SELECT lpep_pickup_day_of_week,STRFTIME('%Y%m%d',lpep_pickup_datetime) as date, count(*) as trip
        FROM nyc_data_sep group by date)
        group by lpep_pickup_day_of_week
        


    """

sqldf(q)
# Out:
#   lpep_pickup_day_of_week  avg(trip)
# 0                  Friday      60.00
# 1                  Monday      41.00
# 2                Saturday      69.25
# 3                  Sunday      55.00
# 4                Thursday      48.00
# 5                 Tuesday      45.40
# 6               Wednesday      36.00

# %%
q = """
        WITH dayly_table AS  (SELECT lpep_pickup_day_of_week,STRFTIME('%Y%m%d',lpep_pickup_datetime) as date, count(*) as trip
            FROM nyc_data_sep group by date)


        select lpep_pickup_day_of_week,avg(trip) from dayly_table
        group by lpep_pickup_day_of_week

    """

sqldf(q)
# Out:
#   lpep_pickup_day_of_week  avg(trip)
# 0                  Friday      60.00
# 1                  Monday      41.00
# 2                Saturday      69.25
# 3                  Sunday      55.00
# 4                Thursday      48.00
# 5                 Tuesday      45.40
# 6               Wednesday      36.00

# %%
#8. Count of trips by hour (Luckily, we have hour column. Otherwise, a new hour column should be created from date column, then count trips by hour).


q = """
        SELECT STRFTIME('%H',lpep_pickup_datetime) as date, count(*) as trip
            FROM nyc_data_sep group by date



    """

sqldf(q)
# Out:
#    date  trip
# 0    00    62
# 1    01    63
# 2    02    31
# 3    03    27
# 4    04    31
# 5    05    11
# 6    06    30
# 7    07    45
# 8    08    63
# 9    09    74
# 10   10    53
# 11   11    64
# 12   12    58
# 13   13    62
# 14   14    60
# 15   15    73
# 16   16    73
# 17   17    90
# 18   18   101
# 19   19    76
# 20   20    92
# 21   21    93
# 22   22    80
# 23   23    88

# %%
#Average passenger count per trip.


q = """
        SELECT AVG(Passenger_count) as Average_passenger_per_trip
        FROM nyc_data_sep 



    """

sqldf(q)
# Out:
#    Average_passenger_per_trip
# 0                    1.328667

# %%
#  10. Average passenger count per trip by hour.
#Average passenger count per trip.


q = """
        SELECT STRFTIME('%H',lpep_pickup_datetime)as Hours,AVG(Passenger_count) as Average_passenger_per_trip
        FROM nyc_data_sep 
        group by STRFTIME('%H',lpep_pickup_datetime)



    """

sqldf(q)
# Out:
#    Hours  Average_passenger_per_trip
# 0     00                    1.483871
# 1     01                    1.396825
# 2     02                    1.161290
# 3     03                    1.444444
# 4     04                    1.129032
# 5     05                    1.818182
# 6     06                    1.333333
# 7     07                    1.288889
# 8     08                    1.301587
# 9     09                    1.270270
# 10    10                    1.056604
# 11    11                    1.187500
# 12    12                    1.258621
# 13    13                    1.306452
# 14    14                    1.166667
# 15    15                    1.369863
# 16    16                    1.383562
# 17    17                    1.322222
# 18    18                    1.485149
# 19    19                    1.250000
# 20    20                    1.293478
# 21    21                    1.376344
# 22    22                    1.437500
# 23    23                    1.431818

# %%
#. Which airport welcomes more passengers: JFK or EWR? Tip: check RateCodeID from data dictionary for the definition (2: JFK, 3: Newark).

q = """
        SELECT RateCodeID, sum(Passenger_count) 
        FROM nyc_data_sep
        where RateCodeID=2 or  RateCodeID=3
        group by RateCodeID


    """

sqldf(q)
# Out:
#    RateCodeID  sum(Passenger_count)
# 0           2                     4
# 1           3                     2

# %%
nyc_data_sep.loc[len(nyc_data_sep)] = [None] * len(nyc_data_sep.columns)
# Out:
# C:\Users\nesri\AppData\Local\Temp\ipykernel_24204\2620669764.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nyc_data_sep.loc[len(nyc_data_sep)] = [None] * len(nyc_data_sep.columns)

# %%
nyc_data_sep.tail()
# Out:
#      VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 1496        2  2015-09-30 22:40:35   2015-09-30 22:49:40                  N
# 1497        2  2015-09-30 23:10:04   2015-09-30 23:26:53                  N
# 1498        2  2015-09-30 23:42:18   2015-09-30 23:46:13                  N
# 1499        2  2015-09-30 23:55:44   2015-10-01 00:02:57                  N
# 1500     None                 None                  None               None
#
#      RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 1496          1        -73.944809        40.829124         -73.960205
# 1497          1        -73.868523        40.749302         -73.918228
# 1498          1        -73.961510        40.719280         -73.951523
# 1499          1        -73.957809        40.731129         -73.956497
# 1500       None               NaN              NaN                NaN
#
#       Dropoff_latitude Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 1496         40.800472               1  ...           0.0        NaN
# 1497         40.736172               1  ...           0.0        NaN
# 1498         40.728699               1  ...           0.0        NaN
# 1499         40.714203               2  ...           0.0        NaN
# 1500               NaN            None  ...           NaN        NaN
#
#       improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 1496                    0.3         10.80             2         1.0
# 1497                    0.3         16.30             2         1.0
# 1498                    0.3          7.56             1         1.0
# 1499                    0.3         10.56             1         1.0
# 1500                    NaN           NaN          None         NaN
#
#       lpep_pickup_hour  lpep_pickup_day_of_week  trip_id driver_id
# 1496                22                Wednesday     1497         5
# 1497                23                Wednesday     1498         1
# 1498                23                Wednesday     1499         3
# 1499                23                Wednesday     1500         5
# 1500              None                     None     None      None
#
# [5 rows x 25 columns]

# %%
# 12. How many nulls are there in Total_amount?

q = """
        SELECT  count (*) as count
        FROM nyc_data_sep
        where Total_amount is null


    """

sqldf(q)
# Out:
#    count
# 0      1

# %%
# !12. How many nulls are there in Total_amount?

q = """
        SELECT  count (Total_amount) as count
        FROM nyc_data_sep
        where Total_amount is null


    """

sqldf(q)
# Out:
#    count
# 0      0

# %%
#How many values are there in Trip_distance? (count of non-missing values)


q = """
        SELECT  count (Trip_distance) as count
        FROM nyc_data_sep
        where Trip_distance is not null


    """

sqldf(q)
# Out:
#    count
# 0   1500

# %%
#How many values are there in Trip_distance? (count of non-missing values)


q = """
        SELECT  count (*) as count
        FROM nyc_data_sep
        where Trip_distance is not null


    """

sqldf(q)
# Out:
#    count
# 0   1500

# %%
#How many nulls are there in Ehail_fee? 
q = """
        SELECT  count (*) as count
        FROM nyc_data_sep
        where Ehail_fee is null


    """

sqldf(q)
# Out:
#    count
# 0   1501

# %%
# ! How many nulls are there in Ehail_fee? 
q = """
        SELECT  count (Ehail_fee) as count
        FROM nyc_data_sep
        where Ehail_fee is null


    """

sqldf(q)
# Out:
#    count
# 0      0

# %%
#Find the trips of which trip distance is greater than 15 miles (included) or less than 0.1 mile (included).
#It is possible to write this with only one where statement. 
#However, this time write two queries and "union" them. The purpose of this question is to use union function.
#You can consider this question as finding outliers in a quick and dirty way, which you would do in your professional life too often.
q = """
        SELECT  * 
        FROM nyc_data_sep
        where Trip_distance >= 15
        union 
        SELECT  * 
        FROM nyc_data_sep
        where Trip_distance <= 0.1


    """

sqldf(q)
# Out:
#     VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0          1  2015-09-01 07:55:42   2015-09-01 07:57:02                  N
# 1          1  2015-09-01 13:29:19   2015-09-01 14:01:59                  Y
# 2          1  2015-09-02 23:43:21   2015-09-02 23:44:04                  N
# 3          1  2015-09-05 20:29:35   2015-09-05 20:30:56                  N
# 4          1  2015-09-09 13:20:19   2015-09-09 13:20:33                  N
# 5          1  2015-09-12 15:28:08   2015-09-12 15:28:52                  N
# 6          1  2015-09-17 21:15:05   2015-09-17 21:52:30                  N
# 7          1  2015-09-24 12:51:50   2015-09-24 13:23:25                  Y
# 8          1  2015-09-27 13:06:07   2015-09-27 13:06:12                  N
# 9          1  2015-09-30 07:58:56   2015-09-30 07:59:41                  N
# 10         2  2015-09-01 04:28:56   2015-09-01 04:28:58                  N
# 11         2  2015-09-01 14:46:59   2015-09-01 15:30:32                  N
# 12         2  2015-09-01 22:18:21   2015-09-01 22:18:26                  N
# 13         2  2015-09-02 09:05:56   2015-09-02 12:45:56                  N
# 14         2  2015-09-02 14:50:46   2015-09-02 14:51:01                  N
# 15         2  2015-09-02 19:56:53   2015-09-02 19:56:57                  N
# 16         2  2015-09-03 13:27:25   2015-09-03 14:07:12                  N
# 17         2  2015-09-04 01:21:13   2015-09-04 01:23:13                  N
# 18         2  2015-09-04 09:22:02   2015-09-04 09:22:40                  N
# 19         2  2015-09-06 12:36:12   2015-09-06 12:44:18                  N
# 20         2  2015-09-07 01:45:10   2015-09-07 02:13:52                  N
# 21         2  2015-09-07 03:40:58   2015-09-07 03:41:14                  N
# 22         2  2015-09-07 16:23:08   2015-09-07 16:23:10                  N
# 23         2  2015-09-09 20:19:09   2015-09-09 20:23:30                  N
# 24         2  2015-09-10 16:34:27   2015-09-10 17:39:59                  N
# 25         2  2015-09-10 17:56:24   2015-09-10 17:56:43                  N
# 26         2  2015-09-11 16:27:01   2015-09-11 17:32:51                  N
# 27         2  2015-09-11 16:34:48   2015-09-11 16:40:49                  N
# 28         2  2015-09-12 16:40:58   2015-09-12 17:15:12                  N
# 29         2  2015-09-12 20:07:57   2015-09-12 20:09:25                  N
# 30         2  2015-09-12 20:35:00   2015-09-12 20:35:00                  N
# 31         2  2015-09-13 01:58:10   2015-09-13 01:58:18                  N
# 32         2  2015-09-13 16:08:43   2015-09-13 16:53:13                  N
# 33         2  2015-09-13 21:59:52   2015-09-13 21:59:54                  N
# 34         2  2015-09-17 12:28:32   2015-09-17 13:02:23                  N
# 35         2  2015-09-17 20:20:08   2015-09-17 20:21:06                  N
# 36         2  2015-09-18 21:25:19   2015-09-18 22:34:45                  N
# 37         2  2015-09-19 19:53:58   2015-09-19 19:54:45                  N
# 38         2  2015-09-20 13:07:50   2015-09-20 13:07:56                  N
# 39         2  2015-09-22 09:58:55   2015-09-22 10:28:38                  N
# 40         2  2015-09-22 13:30:54   2015-09-22 20:34:18                  N
# 41         2  2015-09-24 08:58:39   2015-09-24 08:58:47                  N
# 42         2  2015-09-26 23:07:01   2015-09-26 23:07:06                  N
# 43         2  2015-09-28 01:09:08   2015-09-28 01:40:32                  N
#
#     RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0            1        -73.945419        40.751495         -73.945435
# 1            1        -73.925537        40.761787         -73.790085
# 2            5        -73.956963        40.669540         -73.955902
# 3            1        -73.954666        40.820889         -73.955376
# 4            2        -73.945061        40.751518         -73.945061
# 5            1        -73.997147        40.684212         -73.995384
# 6            1        -73.923180        40.866951         -73.791512
# 7            3        -73.962112        40.809303         -74.177055
# 8            1        -73.936180        40.799328         -73.936180
# 9            1        -73.945610        40.751526         -73.945595
# 10           5          0.000000         0.000000         -73.939354
# 11           1        -73.857430        40.785637         -73.957535
# 12           1        -73.935349        40.679619         -73.938057
# 13           5        -73.864769        40.849461         -73.902870
# 14           1        -73.937210        40.764584         -73.937210
# 15           5        -73.939445        40.805187         -73.939461
# 16           5        -73.827202        40.852108         -73.776306
# 17           1        -73.936874        40.764767         -73.936798
# 18           1        -73.934875        40.682037         -73.934998
# 19           5        -73.894371        40.846558         -73.916100
# 20           1        -73.936958        40.802250         -74.066345
# 21           2        -73.912369        40.767223         -73.912949
# 22           5        -73.861084        40.874367         -73.860954
# 23           1        -73.946869        40.810719         -73.943146
# 24           5        -73.940636        40.814892         -73.782898
# 25           1        -74.002007        40.609333         -74.002007
# 26           1        -73.961914        40.713448         -73.780602
# 27           1        -73.957581        40.717926         -73.952705
# 28           1        -73.845467        40.754745         -74.011307
# 29           1        -73.936691        40.764801         -73.936699
# 30           5        -73.911163        40.862247         -73.911163
# 31           5        -73.925301        40.838509         -73.926033
# 32           3        -73.945396        40.719357         -74.177361
# 33           5        -73.889938        40.869606         -73.889938
# 34           1        -73.918594        40.852985         -73.781235
# 35           1        -73.830429        40.760048         -73.831184
# 36           1        -73.844078        40.756824         -73.959167
# 37           1        -73.945335        40.790646         -73.944550
# 38           1        -73.940491        40.806049         -73.939369
# 39           1        -73.871819        40.734268         -73.508781
# 40           5        -73.953491        40.805447         -73.885094
# 41           2        -73.937447        40.848503         -73.937325
# 42           1        -73.954277        40.816288         -73.953583
# 43           5        -73.896866        40.750179         -73.896278
#
#     Dropoff_latitude  Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 0          40.751499                1  ...          0.00       None
# 1          40.646877                1  ...          0.00       None
# 2          40.668324                1  ...          0.00       None
# 3          40.820217                2  ...          0.00       None
# 4          40.751507                2  ...          0.00       None
# 5          40.683426                1  ...          0.00       None
# 6          40.698406                1  ...          5.54       None
# 7          40.694866                1  ...          9.75       None
# 8          40.799328                1  ...          0.00       None
# 9          40.751530                1  ...          0.00       None
# 10         40.788391                1  ...          0.00       None
# 11         40.670799                3  ...          0.00       None
# 12         40.679790                6  ...          0.00       None
# 13         40.869495                1  ...          0.00       None
# 14         40.764683                1  ...          0.00       None
# 15         40.805183                1  ...          0.00       None
# 16         40.645683                1  ...          0.00       None
# 17         40.764736                1  ...          0.00       None
# 18         40.682995                3  ...          0.00       None
# 19         40.836502                1  ...          0.00       None
# 20         40.798283                1  ...          9.75       None
# 21         40.766487                1  ...          0.00       None
# 22         40.874550                1  ...          0.00       None
# 23         40.821022                1  ...          0.00       None
# 24         40.648796                2  ...          5.54       None
# 25         40.609337                1  ...          0.00       None
# 26         40.646111                1  ...          0.00       None
# 27         40.727226                1  ...          0.00       None
# 28         40.710960                1  ...          5.54       None
# 29         40.764809                1  ...          0.00       None
# 30         40.862267                1  ...          0.00       None
# 31         40.838493                2  ...          0.00       None
# 32         40.695236                1  ...         22.83       None
# 33         40.869606                1  ...          0.00       None
# 34         40.646626                1  ...          5.54       None
# 35         40.760101                1  ...          0.00       None
# 36         40.630295                1  ...          0.00       None
# 37         40.791725                1  ...          0.00       None
# 38         40.807583                1  ...          0.00       None
# 39         40.810638                1  ...          0.00       None
# 40         40.828144                5  ...          0.00       None
# 41         40.848621                1  ...          0.00       None
# 42         40.817154                1  ...          0.00       None
# 43         40.748676                1  ...          5.54       None
#
#     improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                     0.3          3.80             2         1.0
# 1                     0.3         53.15             1         1.0
# 2                     0.0         45.80             1         2.0
# 3                     0.3          4.30             2         1.0
# 4                     0.3         52.80             2         1.0
# 5                     0.3          3.30             3         1.0
# 6                     0.3         59.84             1         1.0
# 7                     0.3         95.55             2         1.0
# 8                     0.3          7.00             1         1.0
# 9                     0.3          3.30             2         1.0
# 10                    0.0         15.00             1         2.0
# 11                    0.3         60.38             1         1.0
# 12                    0.3          3.80             2         1.0
# 13                    0.3         15.30             2         1.0
# 14                    0.3          3.30             2         1.0
# 15                    0.0          8.00             1         2.0
# 16                    0.0         60.00             2         2.0
# 17                    0.3          4.30             1         1.0
# 18                    0.3         13.30             1         1.0
# 19                    0.0         13.00             1         2.0
# 20                    0.3         63.55             2         1.0
# 21                    0.3         52.80             2         1.0
# 22                    0.0         11.00             1         2.0
# 23                    0.3          5.80             1         1.0
# 24                    0.0         50.54             2         2.0
# 25                    0.3          4.30             2         1.0
# 26                    0.3         53.80             2         1.0
# 27                    0.3          7.30             2         1.0
# 28                    0.3         64.61             1         1.0
# 29                    0.3          3.82             1         1.0
# 30                    0.3         19.30             1         2.0
# 31                    0.0         18.00             1         2.0
# 32                    0.3        136.36             1         1.0
# 33                    0.0          7.00             2         2.0
# 34                    0.3         61.34             2         1.0
# 35                    0.3          3.80             2         1.0
# 36                    0.3         78.96             1         1.0
# 37                    0.3          3.30             2         1.0
# 38                    0.3          3.30             2         1.0
# 39                    0.3         65.00             1         1.0
# 40                    0.0          7.00             2         2.0
# 41                    0.3         52.80             2         1.0
# 42                    0.3          3.80             2         1.0
# 43                    0.0         61.04             2         2.0
#
#    lpep_pickup_hour  lpep_pickup_day_of_week  trip_id  driver_id
# 0                 7                  Tuesday        6          1
# 1                13                  Tuesday       16          3
# 2                23                Wednesday       65          3
# 3                20                 Saturday      229          4
# 4                13                Wednesday      407          1
# 5                15                 Saturday      569          5
# 6                21                 Thursday      809          3
# 7                12                 Thursday     1156          3
# 8                13                   Sunday     1344          4
# 9                 7                Wednesday     1471          2
# 10                4                  Tuesday        3          3
# 11               14                  Tuesday       17          1
# 12               22                  Tuesday       33          1
# 13                9                Wednesday       40          1
# 14               14                Wednesday       47          3
# 15               19                Wednesday       59          2
# 16               13                 Thursday       84          5
# 17                1                   Friday      117          3
# 18                9                   Friday      130          2
# 19               12                   Sunday      260          2
# 20                1                   Monday      305          4
# 21                3                   Monday      309          3
# 22               16                   Monday      328          5
# 23               20                Wednesday      422          3
# 24               16                 Thursday      454          5
# 25               17                 Thursday      460          2
# 26               16                   Friday      510          3
# 27               16                   Friday      511          5
# 28               16                 Saturday      574          4
# 29               20                 Saturday      584          5
# 30               20                 Saturday      588          5
# 31                1                   Sunday      615          1
# 32               16                   Sunday      637          1
# 33               21                   Sunday      655          3
# 34               12                 Thursday      788          2
# 35               20                 Thursday      806          4
# 36               21                   Friday      873          2
# 37               19                 Saturday      927          5
# 38               13                   Sunday      975          1
# 39                9                  Tuesday     1064          1
# 40               13                  Tuesday     1071          3
# 41                8                 Thursday     1147          5
# 42               23                 Saturday     1316          3
# 43                1                   Monday     1369          4
#
# [44 rows x 25 columns]

# %%
nyc_data_sep[nyc_data_sep["Trip_distance"]>15]
# Out:
#      VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 16          2  2015-09-01 14:46:59   2015-09-01 15:30:32                  N
# 39          2  2015-09-02 09:05:56   2015-09-02 12:45:56                  N
# 83          2  2015-09-03 13:27:25   2015-09-03 14:07:12                  N
# 304         2  2015-09-07 01:45:10   2015-09-07 02:13:52                  N
# 453         2  2015-09-10 16:34:27   2015-09-10 17:39:59                  N
# 509         2  2015-09-11 16:27:01   2015-09-11 17:32:51                  N
# 573         2  2015-09-12 16:40:58   2015-09-12 17:15:12                  N
# 636         2  2015-09-13 16:08:43   2015-09-13 16:53:13                  N
# 787         2  2015-09-17 12:28:32   2015-09-17 13:02:23                  N
# 808         1  2015-09-17 21:15:05   2015-09-17 21:52:30                  N
# 872         2  2015-09-18 21:25:19   2015-09-18 22:34:45                  N
# 1063        2  2015-09-22 09:58:55   2015-09-22 10:28:38                  N
# 1070        2  2015-09-22 13:30:54   2015-09-22 20:34:18                  N
# 1155        1  2015-09-24 12:51:50   2015-09-24 13:23:25                  Y
# 1368        2  2015-09-28 01:09:08   2015-09-28 01:40:32                  N
#
#      RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 16            1        -73.857430        40.785637         -73.957535
# 39            5        -73.864769        40.849461         -73.902870
# 83            5        -73.827202        40.852108         -73.776306
# 304           1        -73.936958        40.802250         -74.066345
# 453           5        -73.940636        40.814892         -73.782898
# 509           1        -73.961914        40.713448         -73.780602
# 573           1        -73.845467        40.754745         -74.011307
# 636           3        -73.945396        40.719357         -74.177361
# 787           1        -73.918594        40.852985         -73.781235
# 808           1        -73.923180        40.866951         -73.791512
# 872           1        -73.844078        40.756824         -73.959167
# 1063          1        -73.871819        40.734268         -73.508781
# 1070          5        -73.953491        40.805447         -73.885094
# 1155          3        -73.962112        40.809303         -74.177055
# 1368          5        -73.896866        40.750179         -73.896278
#
#       Dropoff_latitude Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 16           40.670799               3  ...          0.00        NaN
# 39           40.869495               1  ...          0.00        NaN
# 83           40.645683               1  ...          0.00        NaN
# 304          40.798283               1  ...          9.75        NaN
# 453          40.648796               2  ...          5.54        NaN
# 509          40.646111               1  ...          0.00        NaN
# 573          40.710960               1  ...          5.54        NaN
# 636          40.695236               1  ...         22.83        NaN
# 787          40.646626               1  ...          5.54        NaN
# 808          40.698406               1  ...          5.54        NaN
# 872          40.630295               1  ...          0.00        NaN
# 1063         40.810638               1  ...          0.00        NaN
# 1070         40.828144               5  ...          0.00        NaN
# 1155         40.694866               1  ...          9.75        NaN
# 1368         40.748676               1  ...          5.54        NaN
#
#       improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 16                      0.3         60.38             1         1.0
# 39                      0.3         15.30             2         1.0
# 83                      0.0         60.00             2         2.0
# 304                     0.3         63.55             2         1.0
# 453                     0.0         50.54             2         2.0
# 509                     0.3         53.80             2         1.0
# 573                     0.3         64.61             1         1.0
# 636                     0.3        136.36             1         1.0
# 787                     0.3         61.34             2         1.0
# 808                     0.3         59.84             1         1.0
# 872                     0.3         78.96             1         1.0
# 1063                    0.3         65.00             1         1.0
# 1070                    0.0          7.00             2         2.0
# 1155                    0.3         95.55             2         1.0
# 1368                    0.0         61.04             2         2.0
#
#       lpep_pickup_hour  lpep_pickup_day_of_week  trip_id driver_id
# 16                  14                  Tuesday       17         1
# 39                   9                Wednesday       40         1
# 83                  13                 Thursday       84         5
# 304                  1                   Monday      305         4
# 453                 16                 Thursday      454         5
# 509                 16                   Friday      510         3
# 573                 16                 Saturday      574         4
# 636                 16                   Sunday      637         1
# 787                 12                 Thursday      788         2
# 808                 21                 Thursday      809         3
# 872                 21                   Friday      873         2
# 1063                 9                  Tuesday     1064         1
# 1070                13                  Tuesday     1071         3
# 1155                12                 Thursday     1156         3
# 1368                 1                   Monday     1369         4
#
# [15 rows x 25 columns]

# %%
nyc_data_sep.loc[16]
pd.concat([nyc_data_sep, nyc_data_sep[nyc_data_sep.index==16]], ignore_index= True)
# Out:
#      VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0           2  2015-09-01 01:17:11   2015-09-01 01:23:01                  N
# 1           2  2015-09-01 02:01:29   2015-09-01 02:22:58                  N
# 2           2  2015-09-01 04:28:56   2015-09-01 04:28:58                  N
# 3           2  2015-09-01 06:56:55   2015-09-01 06:59:09                  N
# 4           2  2015-09-01 07:54:44   2015-09-01 07:57:07                  N
# ...       ...                  ...                   ...                ...
# 1497        2  2015-09-30 23:10:04   2015-09-30 23:26:53                  N
# 1498        2  2015-09-30 23:42:18   2015-09-30 23:46:13                  N
# 1499        2  2015-09-30 23:55:44   2015-10-01 00:02:57                  N
# 1500     None                 None                  None               None
# 1501        2  2015-09-01 14:46:59   2015-09-01 15:30:32                  N
#
#      RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0             1        -73.830284        40.759506         -73.813698
# 1             1        -73.955322        40.720055         -73.906677
# 2             5          0.000000         0.000000         -73.939354
# 3             1        -73.914764        40.763802         -73.921127
# 4             1        -73.894241        40.864166         -73.897781
# ...         ...               ...              ...                ...
# 1497          1        -73.868523        40.749302         -73.918228
# 1498          1        -73.961510        40.719280         -73.951523
# 1499          1        -73.957809        40.731129         -73.956497
# 1500       None               NaN              NaN                NaN
# 1501          1        -73.857430        40.785637         -73.957535
#
#       Dropoff_latitude Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 0            40.751537               2  ...           0.0        NaN
# 1            40.684845               1  ...           0.0        NaN
# 2            40.788391               1  ...           0.0        NaN
# 3            40.766788               1  ...           0.0        NaN
# 4            40.870739               1  ...           0.0        NaN
# ...                ...             ...  ...           ...        ...
# 1497         40.736172               1  ...           0.0        NaN
# 1498         40.728699               1  ...           0.0        NaN
# 1499         40.714203               2  ...           0.0        NaN
# 1500               NaN            None  ...           NaN        NaN
# 1501         40.670799               3  ...           0.0        NaN
#
#       improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                       0.3          7.80             2         1.0
# 1                       0.3         22.56             1         1.0
# 2                       0.0         15.00             1         2.0
# 3                       0.3          5.38             1         1.0
# 4                       0.3          6.24             1         1.0
# ...                     ...           ...           ...         ...
# 1497                    0.3         16.30             2         1.0
# 1498                    0.3          7.56             1         1.0
# 1499                    0.3         10.56             1         1.0
# 1500                    NaN           NaN          None         NaN
# 1501                    0.3         60.38             1         1.0
#
#       lpep_pickup_hour  lpep_pickup_day_of_week  trip_id driver_id
# 0                    1                  Tuesday        1         2
# 1                    2                  Tuesday        2         2
# 2                    4                  Tuesday        3         3
# 3                    6                  Tuesday        4         5
# 4                    7                  Tuesday        5         2
# ...                ...                      ...      ...       ...
# 1497                23                Wednesday     1498         1
# 1498                23                Wednesday     1499         3
# 1499                23                Wednesday     1500         5
# 1500              None                     None     None      None
# 1501                14                  Tuesday       17         1
#
# [1502 rows x 25 columns]

# %%
nyc_data_sep.loc[len(nyc_data_sep)]=nyc_data_sep.loc[16]

# %%
nyc_data_sep.tail()
# Out:
#      VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 1497        2  2015-09-30 23:10:04   2015-09-30 23:26:53                  N
# 1498        2  2015-09-30 23:42:18   2015-09-30 23:46:13                  N
# 1499        2  2015-09-30 23:55:44   2015-10-01 00:02:57                  N
# 1500     None                 None                  None               None
# 1501        2  2015-09-01 14:46:59   2015-09-01 15:30:32                  N
#
#      RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 1497          1        -73.868523        40.749302         -73.918228
# 1498          1        -73.961510        40.719280         -73.951523
# 1499          1        -73.957809        40.731129         -73.956497
# 1500       None               NaN              NaN                NaN
# 1501          1        -73.857430        40.785637         -73.957535
#
#       Dropoff_latitude Passenger_count  ...  Tolls_amount  Ehail_fee  \
# 1497         40.736172               1  ...           0.0        NaN
# 1498         40.728699               1  ...           0.0        NaN
# 1499         40.714203               2  ...           0.0        NaN
# 1500               NaN            None  ...           NaN        NaN
# 1501         40.670799               3  ...           0.0        NaN
#
#       improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 1497                    0.3         16.30             2         1.0
# 1498                    0.3          7.56             1         1.0
# 1499                    0.3         10.56             1         1.0
# 1500                    NaN           NaN          None         NaN
# 1501                    0.3         60.38             1         1.0
#
#       lpep_pickup_hour  lpep_pickup_day_of_week  trip_id driver_id
# 1497                23                Wednesday     1498         1
# 1498                23                Wednesday     1499         3
# 1499                23                Wednesday     1500         5
# 1500              None                     None     None      None
# 1501                14                  Tuesday       17         1
#
# [5 rows x 25 columns]

# %%
#We would like to see the distribution (not like histogram) of Total_amount. 
#Could you create buckets, or price range, for Total_amount and find how many trips there are in each buckets? 
#Each range would be 5, until 35, i.e. 0-5, 5-10, 10-15 … 30-35, +35. The expected output would be as follows:

q = """
       SELECT Total_amount,
               CASE WHEN Total_amount < 5 THEN '0 - 5'
                    WHEN Total_amount >= 5 AND Total_amount < 10 THEN '5 - 10'
                    WHEN Total_amount >= 10 AND Total_amount < 15 THEN '10 - 15'
                    WHEN Total_amount >= 15 AND Total_amount < 20 THEN '15 - 20'
                    WHEN Total_amount >= 20 AND Total_amount < 25 THEN '20 - 25'
                    WHEN Total_amount >= 25 AND Total_amount < 30 THEN '25 - 30'
                    WHEN Total_amount >= 30 AND Total_amount < 35 THEN '30 - 35'
                    WHEN Total_amount >= 35 THEN '35+' END as Payment_Range_in_Dollars
        FROM nyc_data_sep


    """

sqldf(q)
# Out:
#       Total_amount Payment_Range_in_Dollars
# 0             7.80                   5 - 10
# 1            22.56                  20 - 25
# 2            15.00                  15 - 20
# 3             5.38                   5 - 10
# 4             6.24                   5 - 10
# ...            ...                      ...
# 1497         16.30                  15 - 20
# 1498          7.56                   5 - 10
# 1499         10.56                  10 - 15
# 1500           NaN                     None
# 1501         60.38                      35+
#
# [1502 rows x 2 columns]

# %%
q = """
       SELECT Payment_Range_in_Dollars, COUNT(*) as trip FROM (SELECT Total_amount,
               CASE WHEN Total_amount < 5 THEN '0 - 5'
                    WHEN Total_amount >= 5 AND Total_amount < 10 THEN '5 - 10'
                    WHEN Total_amount >= 10 AND Total_amount < 15 THEN '10 - 15'
                    WHEN Total_amount >= 15 AND Total_amount < 20 THEN '15 - 20'
                    WHEN Total_amount >= 20 AND Total_amount < 25 THEN '20 - 25'
                    WHEN Total_amount >= 25 AND Total_amount < 30 THEN '25 - 30'
                    WHEN Total_amount >= 30 AND Total_amount < 35 THEN '30 - 35'
                    WHEN Total_amount >= 35 THEN '35+' END as Payment_Range_in_Dollars
        FROM nyc_data_sep)
        group by Payment_Range_in_Dollars
        order by trip


    """

sqldf(q)
# Out:
#   Payment_Range_in_Dollars  trip
# 0                     None     1
# 1                  30 - 35    42
# 2                    0 - 5    47
# 3                  25 - 30    60
# 4                      35+    97
# 5                  20 - 25   103
# 6                  15 - 20   214
# 7                  10 - 15   385
# 8                   5 - 10   553

# %%
q = """
       with tamp_table  as (SELECT Total_amount,
               CASE WHEN Total_amount < 5 THEN '0 - 5'
                    WHEN Total_amount >= 5 AND Total_amount < 10 THEN '5 - 10'
                    WHEN Total_amount >= 10 AND Total_amount < 15 THEN '10 - 15'
                    WHEN Total_amount >= 15 AND Total_amount < 20 THEN '15 - 20'
                    WHEN Total_amount >= 20 AND Total_amount < 25 THEN '20 - 25'
                    WHEN Total_amount >= 25 AND Total_amount < 30 THEN '25 - 30'
                    WHEN Total_amount >= 30 AND Total_amount < 35 THEN '30 - 35'
                    WHEN Total_amount >= 35 THEN '35+' END as Payment_Range_in_Dollars
        FROM nyc_data_sep)
        Select Payment_Range_in_Dollars, count(*) as trip 
        From tamp_table
        Group By Payment_Range_in_Dollars

    """

sqldf(q)
# Out:
#   Payment_Range_in_Dollars  trip
# 0                     None     1
# 1                    0 - 5    47
# 2                  10 - 15   385
# 3                  15 - 20   214
# 4                  20 - 25   103
# 5                  25 - 30    60
# 6                  30 - 35    42
# 7                      35+    97
# 8                   5 - 10   553

# %%
#Count missing valueleri saymiyor
q = """
       with tamp_table  as (SELECT Total_amount,
               CASE WHEN Total_amount < 5 THEN '0 - 5'
                    WHEN Total_amount >= 5 AND Total_amount < 10 THEN '5 - 10'
                    WHEN Total_amount >= 10 AND Total_amount < 15 THEN '10 - 15'
                    WHEN Total_amount >= 15 AND Total_amount < 20 THEN '15 - 20'
                    WHEN Total_amount >= 20 AND Total_amount < 25 THEN '20 - 25'
                    WHEN Total_amount >= 25 AND Total_amount < 30 THEN '25 - 30'
                    WHEN Total_amount >= 30 AND Total_amount < 35 THEN '30 - 35'
                    WHEN Total_amount >= 35 THEN '35+' END as Payment_Range_in_Dollars
        FROM nyc_data_sep)
        Select Payment_Range_in_Dollars, count(Payment_Range_in_Dollars) as trip 
        From tamp_table
        Group By Payment_Range_in_Dollars

    """

sqldf(q)
# Out:
#   Payment_Range_in_Dollars  trip
# 0                     None     0
# 1                    0 - 5    47
# 2                  10 - 15   385
# 3                  15 - 20   214
# 4                  20 - 25   103
# 5                  25 - 30    60
# 6                  30 - 35    42
# 7                      35+    97
# 8                   5 - 10   553

# %%
q = """
        SELECT
            CASE
                WHEN Total_amount BETWEEN 0 and 5 THEN '0-5'
                WHEN Total_amount BETWEEN 5 and 10 THEN '5-10'
                WHEN Total_amount BETWEEN 10 and 15 THEN '10-15'
                WHEN Total_amount BETWEEN 15 and 20 THEN '15-20'
                WHEN Total_amount BETWEEN 20 and 25 THEN '20-25'
                WHEN Total_amount BETWEEN 25 and 30 THEN '25-30'
                WHEN Total_amount BETWEEN 30 and 35 THEN '30-35'
                ELSE '35+'
            END as buckets,
            count(*) as trip_cpunt
        FROM nyc_data_sep
        GROUP BY buckets;
    """

sqldf(q)
# Out:
#   buckets  trip_cpunt
# 0     0-5          45
# 1   10-15         384
# 2   15-20         213
# 3   20-25         103
# 4   25-30          58
# 5   30-35          42
# 6     35+         100
# 7    5-10         557

# %%
#Could you find the highest 3 Total_amount trips for each driver? Hint: Use “Window” functions.
q = """
       SELECT distinct driver_id
        FROM nyc_data_sep
        

    """

sqldf(q)
# Out:
#    driver_id
# 0        2.0
# 1        3.0
# 2        5.0
# 3        1.0
# 4        4.0
# 5        NaN

# %%
q = """
       WITH temp_table AS (SELECT driver_id, total_amount,
               RANK() OVER(PARTITION BY Driver_ID ORDER BY Total_amount DESC) as Rnk              
        FROM nyc_data_sep)
        
        SELECT * FROM temp_table 
        WHERE Rnk <= 3

    """

sqldf(q)
# Out:
#     driver_id  total_amount  Rnk
# 0         NaN           NaN    1
# 1         1.0        136.36    1
# 2         1.0         84.75    2
# 3         1.0         65.00    3
# 4         2.0         78.96    1
# 5         2.0         61.34    2
# 6         2.0         57.64    3
# 7         3.0         95.55    1
# 8         3.0         59.84    2
# 9         3.0         55.56    3
# 10        4.0         64.61    1
# 11        4.0         63.55    2
# 12        4.0         61.04    3
# 13        5.0         80.16    1
# 14        5.0         60.00    2
# 15        5.0         54.10    3

# %%
#19.Could you find the lowest 3 Total_amount trips for each driver? Hint: Use “Window” functions
q = """
       WITH temp_table AS (SELECT driver_id, total_amount,
               RANK() OVER(PARTITION BY Driver_ID ORDER BY Total_amount ASC) as Rnk              
        FROM nyc_data_sep)
        
        SELECT * FROM temp_table 
        WHERE Rnk <= 5

    """

sqldf(q)
# Out:
#     driver_id  total_amount  Rnk
# 0         NaN           NaN    1
# 1         1.0          0.00    1
# 2         1.0          3.30    2
# 3         1.0          3.30    2
# 4         1.0          3.80    4
# 5         1.0          3.80    4
# 6         2.0          0.00    1
# 7         2.0          3.30    2
# 8         2.0          4.30    3
# 9         2.0          4.30    3
# 10        2.0          4.80    5
# 11        2.0          4.80    5
# 12        2.0          4.80    5
# 13        3.0         -5.30    1
# 14        3.0          3.30    2
# 15        3.0          3.80    3
# 16        3.0          4.30    4
# 17        3.0          4.30    4
# 18        3.0          4.30    4
# 19        4.0         -6.80    1
# 20        4.0          0.00    2
# 21        4.0          3.80    3
# 22        4.0          4.30    4
# 23        4.0          4.30    4
# 24        5.0          3.30    1
# 25        5.0          3.30    1
# 26        5.0          3.82    3
# 27        5.0          4.30    4
# 28        5.0          4.30    4
# 29        5.0          4.30    4
# 30        5.0          4.30    4

# %%
#20.Could you find the lowest 10 Total_amount trips for driver_id 1? Do you see any anomaly in the rank? (same rank, missing rank etc).
#Could you “fix” that so that ranking would be 1, 2, 3, 4… (without any missing rank)? 
#Note that 1 is the lowest Total_amount in this question. Also, same ranks would continue to exist since there might be the same Total_amount. 
#Hint: dense_rank.
q = """
       WITH temp_table AS (SELECT driver_id, total_amount,
               DENSE_RANK() OVER(PARTITION BY Driver_ID ORDER BY Total_amount ASC) as Rnk              
        FROM nyc_data_sep)
        
        SELECT * FROM temp_table 
        WHERE  driver_id =1 AND Rnk <= 10

    """

sqldf(q)
# Out:
#     driver_id  total_amount  Rnk
# 0           1          0.00    1
# 1           1          3.30    2
# 2           1          3.30    2
# 3           1          3.80    3
# 4           1          3.80    3
# 5           1          4.30    4
# 6           1          4.30    4
# 7           1          4.80    5
# 8           1          4.80    5
# 9           1          4.80    5
# 10          1          4.80    5
# 11          1          4.80    5
# 12          1          4.80    5
# 13          1          4.80    5
# 14          1          5.30    6
# 15          1          5.30    6
# 16          1          5.30    6
# 17          1          5.30    6
# 18          1          5.30    6
# 19          1          5.30    6
# 20          1          5.80    7
# 21          1          5.80    7
# 22          1          5.80    7
# 23          1          5.80    7
# 24          1          5.80    7
# 25          1          5.80    7
# 26          1          5.80    7
# 27          1          5.80    7
# 28          1          5.80    7
# 29          1          5.80    7
# 30          1          5.80    7
# 31          1          5.80    7
# 32          1          5.80    7
# 33          1          5.80    7
# 34          1          6.30    8
# 35          1          6.30    8
# 36          1          6.30    8
# 37          1          6.30    8
# 38          1          6.30    8
# 39          1          6.30    8
# 40          1          6.30    8
# 41          1          6.36    9
# 42          1          6.36    9
# 43          1          6.36    9
# 44          1          6.62   10

# %%
q = """
       WITH temp_table AS (SELECT driver_id, total_amount,
               RANK() OVER(PARTITION BY Driver_ID ORDER BY Total_amount ASC) as Rnk              
        FROM nyc_data_sep)
        
        SELECT * FROM temp_table 
        WHERE  driver_id =1 AND Rnk <= 10

    """

sqldf(q)
# Out:
#     driver_id  total_amount  Rnk
# 0           1           0.0    1
# 1           1           3.3    2
# 2           1           3.3    2
# 3           1           3.8    4
# 4           1           3.8    4
# 5           1           4.3    6
# 6           1           4.3    6
# 7           1           4.8    8
# 8           1           4.8    8
# 9           1           4.8    8
# 10          1           4.8    8
# 11          1           4.8    8
# 12          1           4.8    8
# 13          1           4.8    8

# %%
#21.Our friend, driver_id 1, is very happy to see what we have done for her (Yes, it is “her”. Her name is Gertrude Jeannette, 
#https://en.wikipedia.org/wiki/Gertrude_Jeannette. That is why her id is 1). 
#Could you do her a favor and track her earning after each trip?
#She would be very thankful if we can provide her with the following information:

q = """
       SELECT driver_id, total_amount,
               SUM(total_amount) OVER(PARTITION BY Driver_ID ORDER BY lpep_pickup_datetime ) as Cum_Sum              
        FROM nyc_data_sep
        WHERE Driver_ID =1

    """

sqldf(q)
# Out:
#      driver_id  Total_amount  Cum_Sum
# 0            1          3.80     3.80
# 1            1          8.30    12.10
# 2            1         25.30    37.40
# 3            1          6.80    44.20
# 4            1         60.38   164.96
# ..         ...           ...      ...
# 315          1         36.96  4919.62
# 316          1          7.80  4927.42
# 317          1          9.75  4937.17
# 318          1         12.80  4949.97
# 319          1         16.30  4966.27
#
# [320 rows x 3 columns]

# %%
q = """
       SELECT driver_id, total_amount,
               SUM(total_amount) OVER(PARTITION BY Driver_ID ) as tot_amount_per_driver              
        FROM nyc_data_sep
        WHERE Driver_ID =1

    """

sqldf(q)
# Out:
#      driver_id  Total_amount  tot_amount_per_driver
# 0            1          3.80                4966.27
# 1            1          8.30                4966.27
# 2            1         25.30                4966.27
# 3            1          6.80                4966.27
# 4            1         60.38                4966.27
# ..         ...           ...                    ...
# 315          1          7.80                4966.27
# 316          1          9.75                4966.27
# 317          1         12.80                4966.27
# 318          1         16.30                4966.27
# 319          1         60.38                4966.27
#
# [320 rows x 3 columns]

# %%
q = """
       SELECT driver_id, total_amount,
               AVG(total_amount) OVER(PARTITION BY Driver_ID ORDER BY lpep_pickup_datetime ) as AVG_Sum              
        FROM nyc_data_sep
        WHERE Driver_ID =1

    """

sqldf(q)
# Out:
#      driver_id  Total_amount    AVG_Sum
# 0            1          3.80   3.800000
# 1            1          8.30   6.050000
# 2            1         25.30  12.466667
# 3            1          6.80  11.050000
# 4            1         60.38  27.493333
# ..         ...           ...        ...
# 315          1         36.96  15.568418
# 316          1          7.80  15.543912
# 317          1          9.75  15.525692
# 318          1         12.80  15.517147
# 319          1         16.30  15.519594
#
# [320 rows x 3 columns]

# %%
#22. Gertrude is fascinated by your work and would like you to find max and min Total_amount. 

q = """
       SELECT driver_id,
              MIN(total_amount) as total_amount
        FROM nyc_data_sep
        WHERE Driver_ID =1
        UNION
        SELECT driver_id,
              MAX(total_amount) as total_amount
        FROM nyc_data_sep
        WHERE Driver_ID =1

    """

sqldf(q)
# Out:
#    driver_id  total_amount
# 0          1          0.00
# 1          1        136.36

# %%
q = """
       WITH temp_table AS
       (SELECT driver_id, total_amount,
               MAX(total_amount) OVER(PARTITION BY Driver_ID ) as Max_total_amount,           

               MIN(total_amount) OVER(PARTITION BY Driver_ID ) as Min_total_amount 
              
              FROM nyc_data_sep
        WHERE Driver_ID =1) 
        SELECT * FROM temp_table WHERE Max_total_amount!=136.36

    """

sqldf(q)
# Out:
# Empty DataFrame
# Columns: [driver_id, total_amount, Max_total_amount, Min_total_amount]
# Index: []

# %%
q = """
       WITH temp_table AS
       (SELECT driver_id, total_amount,
               MAX(total_amount) OVER(PARTITION BY Driver_ID ) as Max_total_amount,           

               MIN(total_amount) OVER(PARTITION BY Driver_ID ) as Min_total_amount 
              
              FROM nyc_data_sep
        WHERE Driver_ID =1)  
        SELECT * FROM temp_table
   
   """

sqldf(q)
# Out:
#      driver_id  total_amount  Max_total_amount  Min_total_amount
# 0            1          3.80            136.36               0.0
# 1            1          8.30            136.36               0.0
# 2            1         25.30            136.36               0.0
# 3            1          6.80            136.36               0.0
# 4            1         60.38            136.36               0.0
# ..         ...           ...               ...               ...
# 315          1          7.80            136.36               0.0
# 316          1          9.75            136.36               0.0
# 317          1         12.80            136.36               0.0
# 318          1         16.30            136.36               0.0
# 319          1         60.38            136.36               0.0
#
# [320 rows x 4 columns]

# %%
q = """ SELECT * 
        FROM
            (SELECT Total_amount,
            RANK () OVER(PARTITION BY Driver_ID ORDER BY Total_amount) Rnk,    
            RANK () OVER(PARTITION BY Driver_ID ORDER BY Total_amount DESC) Inverse_Rnk
            FROM nyc_data_sep
            WHERE Driver_ID = 1)
        WHERE Rnk = 1 OR Inverse_Rnk = 1
  
    """


sqldf(q)
# Out:
#    Total_amount  Rnk  Inverse_Rnk
# 0          0.00    1          320
# 1        136.36  320            1

# %%
#23.There is one thing that Gertrude could not understand. 
#Min Total_amount is 0, however we did not show any 0 while we track her earning (in cumulative sum question). 
#It seems we owe her an explanation. Why do you think this happened?

# %%
#24.Is there any new driver in October? Hint: Drivers existing in one table but not in another table.
q = """ SELECT DISTINCT Driver_ID
        FROM nyc_data_oct
        WHERE Driver_ID NOT IN
        (SELECT DISTINCT Driver_ID
        FROM nyc_data_sep WHERE Driver_ID is not null)
  
    """


sqldf(q)
# Out:
#    driver_id
# 0          7
# 1          6

# %%
q = """ SELECT DISTINCT Driver_ID
        FROM nyc_data_oct
       
  
    """


sqldf(q)
# Out:
#    driver_id
# 0          7
# 1          5
# 2          1
# 3          6
# 4          2
# 5          4
# 6          3

# %%
q = """ SELECT DISTINCT Driver_ID
        FROM nyc_data_sep
       WHERE Driver_ID is not null
  
    """


sqldf(q)
# Out:
#    driver_id
# 0          2
# 1          3
# 2          5
# 3          1
# 4          4
